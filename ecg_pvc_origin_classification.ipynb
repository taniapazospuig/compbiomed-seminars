# %%
import pickle
import pandas as pd

# Load the large dataset
with open("data/all_points_may_2024.pkl", "rb") as file:
    all_points = pickle.load(file)

# Explore the structure
print(f"Top-level type: {type(all_points)}")
print(f"Number of patient entries: {len(all_points)}")
# Out:
# Top-level type: <class 'dict'>
# Number of patient entries: 190

# %% [markdown]
# Hence, the dataset contains data for 190 patients.
# For each patient:
# * Metadata: Sex, HTA, Age, PVC_transition, SOO_chamber, Height, Weight, BMI, DM, DLP, Smoker, COPD, Sleep_apnea, CLINICAL_SCORE, SOO, OTorigin.
# * Structures

# %%
# Initial inspection of metadata only (one row per patient)
overview_metadata = []
for patient_id, patient_data in all_points.items():
    overview_metadata.append({
        "PatientID": patient_id,
        "Sex": patient_data.get("Sex", [None])[0],
        "Age": patient_data.get("Age", [None])[0],
        "PVC_transition": patient_data.get("PVC_transition", [None])[0],
        "SOO_chamber": patient_data.get("SOO_chamber", [None])[0],
        "Height": patient_data.get("Height", [None])[0],
        "Weight": patient_data.get("Weight", [None])[0],
        "BMI": patient_data.get("BMI", [None])[0],
        "DM": patient_data.get("DM", [None])[0],
        "DLP": patient_data.get("DLP", [None])[0],
        "Smoker": patient_data.get("Smoker", [None])[0],
        "COPD": patient_data.get("COPD", [None])[0],
        "Sleep_apnea": patient_data.get("Sleep_apnea", [None])[0],
        "CLINICAL_SCORE": patient_data.get("CLINICAL_SCORE", [None])[0],
        "SOO": patient_data.get("SOO", [None])[0],
        "OTorigin": patient_data.get("OTorigin", [None])[0],
        "Structures": patient_data.get("Structures", {})
    })

df_meta_overview = pd.DataFrame(overview_metadata)
print("Metadata overview shape (patients):", df_meta_overview.shape)
df_meta_overview.head()
# Out:
# Metadata overview shape (patients): (190, 17)
#   PatientID     Sex   Age PVC_transition      SOO_chamber  Height  Weight  \
# 0      P186  Female  61.0             V1  Right ventricle     NaN     NaN
# 1      P245  Female  52.0             V3             RVOT   169.0    68.0
# 2      P292  Female  69.0             V3             LVOT   156.0    70.0
# 3      P205  Female  66.0             V4  Right ventricle   176.0    63.0
# 4      P066  Female  46.0             V3             RVOT   160.0    79.0
#
#          BMI   DM  DLP Smoker COPD Sleep_apnea  CLINICAL_SCORE  \
# 0        NaN  NaN  NaN    NaN  NaN         NaN             NaN
# 1        NaN   No   No     No   No          No             1.0
# 2        NaN   No  Yes     No   No          No             1.0
# 3  20.338326   No   No     No   No          No             1.0
# 4  30.859375   No   No     No   No          No             1.0
#
#                         SOO  OTorigin  \
# 0        Unión mitroaórtica       0.0
# 1      Pared libre anterior       1.0
# 2                       RCC       1.0
# 3  M. papilar posteromedial       0.0
# 4               RVOT septal       1.0
#
#                                           Structures
# 0  {'2-LV': {'P36': {'I': [-0.075 -0.075 -0.072 ....
# 1  {'2-RV': {'P157': {'I': [ 0.     0.     0.    ...
# 2  {'2-AO': {'P55': {'I': [-0.063 -0.051 -0.03  ....
# 3  {'2-1-Rp-LV': {'P320': {'I': [-0.297 -0.288 -0...
# 4  {'1-PA': {'P13': {'I': [-0.006 -0.003 -0.003 ....

# %%
# Check the structure of the first patient
df_meta_overview["Structures"][0]
# Out:
# {'2-LV': {'P36': {'I': array([-0.075, -0.075, -0.072, ..., -0.039, -0.039, -0.036]),
#    'II': array([-0.045, -0.048, -0.048, ...,  0.09 ,  0.09 ,  0.087]),
#    'III': array([0.03 , 0.027, 0.024, ..., 0.132, 0.129, 0.123]),
#    'AVR': array([-0.051, -0.051, -0.048, ..., -0.087, -0.084, -0.078]),
#    'AVL': array([ 0.06 ,  0.06 ,  0.06 , ..., -0.024, -0.024, -0.024]),
#    'AVF': array([-0.006, -0.009, -0.009, ...,  0.111,  0.108,  0.105]),
#    'V1': array([0.093, 0.093, 0.09 , ..., 0.021, 0.021, 0.018]),
#    'V2': array([ 0.078,  0.075,  0.075, ..., -0.006, -0.006, -0.006]),
#    'V3': array([0.078, 0.078, 0.075, ..., 0.129, 0.126, 0.126]),
#    'V4': array([0.024, 0.024, 0.021, ..., 0.117, 0.117, 0.114]),
#    'V5': array([-0.024, -0.027, -0.03 , ...,  0.093,  0.093,  0.09 ]),
#    'V6': array([-0.054, -0.054, -0.057, ...,  0.063,  0.063,  0.063])},
#   'P122': {'I': array([-0.042, -0.045, -0.048, ..., -0.078, -0.072, -0.072]),
#    'II': array([-0.015, -0.015, -0.012, ...,  0.117,  0.12 ,  0.12 ]),
#    'III': array([0.027, 0.03 , 0.033, ..., 0.195, 0.195, 0.198]),
#    'AVR': array([-0.033, -0.039, -0.042, ..., -0.138, -0.132, -0.135]),
#    'AVL': array([ 0.027,  0.03 ,  0.03 , ..., -0.018, -0.021, -0.024]),
#    'AVF': array([0.006, 0.006, 0.009, ..., 0.156, 0.159, 0.159]),
#    'V1': array([0.054, 0.054, 0.054, ..., 0.078, 0.078, 0.075]),
#    'V2': array([ 0.03 ,  0.033,  0.033, ..., -0.024, -0.027, -0.027]),
#    'V3': array([0.027, 0.027, 0.03 , ..., 0.147, 0.147, 0.15 ]),
#    'V4': array([-0.057, -0.054, -0.051, ...,  0.105,  0.108,  0.108]),
#    'V5': array([-0.096, -0.093, -0.09 , ...,  0.069,  0.069,  0.069]),
#    'V6': array([-0.105, -0.105, -0.102, ...,  0.03 ,  0.03 ,  0.03 ])},
#   'P85': {'I': array([-0.048, -0.045, -0.042, ..., -0.015, -0.012, -0.006]),
#    'II': array([-0.021, -0.021, -0.021, ...,  0.111,  0.117,  0.123]),
#    'III': array([0.021, 0.021, 0.021, ..., 0.132, 0.132, 0.132]),
#    'AVR': array([-0.033, -0.033, -0.033, ..., -0.075, -0.072, -0.069]),
#    'AVL': array([ 0.036,  0.033,  0.03 , ..., -0.048, -0.051, -0.057]),
#    'AVF': array([0.   , 0.   , 0.   , ..., 0.12 , 0.123, 0.126]),
#    'V1': array([0.042, 0.042, 0.042, ..., 0.018, 0.015, 0.012]),
#    'V2': array([0.015, 0.015, 0.015, ..., 0.021, 0.021, 0.015]),
#    'V3': array([-0.006, -0.006, -0.006, ...,  0.15 ,  0.156,  0.159]),
#    'V4': array([-0.087, -0.087, -0.087, ...,  0.135,  0.141,  0.144]),
#    'V5': array([-0.144, -0.144, -0.144, ...,  0.111,  0.114,  0.114]),
#    'V6': array([-0.15 , -0.15 , -0.15 , ...,  0.066,  0.066,  0.066])},
#   'P103': {'I': array([-0.045, -0.048, -0.048, ..., -0.024, -0.03 , -0.033]),
#    'II': array([-0.042, -0.045, -0.045, ...,  0.105,  0.102,  0.099]),
#    'III': array([0.003, 0.003, 0.   , ..., 0.132, 0.135, 0.135]),
#    'AVR': array([-0.024, -0.027, -0.024, ..., -0.078, -0.081, -0.084]),
#    'AVL': array([ 0.042,  0.045,  0.048, ..., -0.039, -0.036, -0.033]),
#    'AVF': array([-0.018, -0.018, -0.021, ...,  0.117,  0.12 ,  0.117]),
#    'V1': array([0.063, 0.063, 0.06 , ..., 0.021, 0.024, 0.027]),
#    'V2': array([0.078, 0.078, 0.078, ..., 0.033, 0.036, 0.036]),
#    'V3': array([0.042, 0.042, 0.042, ..., 0.156, 0.159, 0.159]),
#    'V4': array([0.003, 0.003, 0.003, ..., 0.144, 0.144, 0.144]),
#    'V5': array([-0.045, -0.045, -0.045, ...,  0.12 ,  0.12 ,  0.12 ]),
#    'V6': array([-0.072, -0.072, -0.069, ...,  0.093,  0.096,  0.096])},
#   'P86': {'I': array([ 0.003,  0.009,  0.015, ..., -0.018, -0.012, -0.009]),
#    'II': array([0.009, 0.006, 0.009, ..., 0.117, 0.111, 0.108]),
#    'III': array([ 0.006,  0.   , -0.003, ...,  0.138,  0.129,  0.123]),
#    'AVR': array([ 0.   ,  0.003,  0.009, ..., -0.078, -0.072, -0.066]),
#    'AVL': array([-0.006, -0.006, -0.012, ..., -0.048, -0.048, -0.048]),
#    'AVF': array([0.006, 0.003, 0.   , ..., 0.126, 0.12 , 0.117]),
#    'V1': array([-0.036, -0.036, -0.036, ...,  0.021,  0.021,  0.018]),
#    'V2': array([-0.006, -0.009, -0.006, ...,  0.045,  0.042,  0.039]),
#    'V3': array([0.033, 0.03 , 0.03 , ..., 0.186, 0.18 , 0.177]),
#    'V4': array([0.066, 0.063, 0.063, ..., 0.156, 0.147, 0.144]),
#    'V5': array([0.075, 0.072, 0.072, ..., 0.117, 0.111, 0.108]),
#    'V6': array([0.054, 0.054, 0.051, ..., 0.09 , 0.084, 0.084])},
#   'P42': {'I': array([-0.045, -0.042, -0.036, ..., -0.066, -0.069, -0.069]),
#    'II': array([-0.069, -0.069, -0.066, ...,  0.054,  0.054,  0.054]),
#    'III': array([-0.024, -0.027, -0.033, ...,  0.123,  0.126,  0.126]),
#    'AVR': array([-0.009, -0.006, -0.003, ..., -0.096, -0.096, -0.096]),
#    'AVL': array([0.057, 0.054, 0.051, ..., 0.006, 0.006, 0.006]),
#    'AVF': array([-0.045, -0.048, -0.051, ...,  0.087,  0.09 ,  0.09 ]),
#    'V1': array([0.048, 0.048, 0.045, ..., 0.042, 0.045, 0.045]),
#    'V2': array([-0.006, -0.006, -0.009, ..., -0.024, -0.021, -0.021]),
#    'V3': array([0.057, 0.054, 0.051, ..., 0.078, 0.081, 0.081]),
#    'V4': array([0.024, 0.024, 0.021, ..., 0.054, 0.057, 0.054]),
#    'V5': array([0.012, 0.009, 0.009, ..., 0.03 , 0.033, 0.033]),
#    'V6': array([0.015, 0.012, 0.012, ..., 0.009, 0.009, 0.009])},
#   'P3': {'I': array([-0.039, -0.039, -0.039, ..., -0.027, -0.021, -0.012]),
#    'II': array([0.006, 0.006, 0.006, ..., 0.09 , 0.09 , 0.09 ]),
#    'III': array([0.045, 0.042, 0.045, ..., 0.12 , 0.114, 0.105]),
#    'AVR': array([-0.042, -0.039, -0.042, ..., -0.075, -0.066, -0.06 ]),
#    'AVL': array([ 0.015,  0.015,  0.015, ..., -0.03 , -0.033, -0.039]),
#    'AVF': array([0.027, 0.024, 0.027, ..., 0.105, 0.102, 0.099]),
#    'V1': array([0.072, 0.069, 0.072, ..., 0.009, 0.006, 0.006]),
#    'V2': array([0.087, 0.087, 0.087, ..., 0.024, 0.021, 0.018]),
#    'V3': array([0.192, 0.189, 0.192, ..., 0.099, 0.096, 0.093]),
#    'V4': array([0.114, 0.114, 0.114, ..., 0.123, 0.12 , 0.117]),
#    'V5': array([0.021, 0.018, 0.021, ..., 0.12 , 0.117, 0.114]),
#    'V6': array([-0.033, -0.033, -0.033, ...,  0.099,  0.099,  0.096])},
#   'P65': {'I': array([-0.045, -0.048, -0.051, ..., -0.012, -0.018, -0.021]),
#    'II': array([-0.009, -0.009, -0.009, ...,  0.105,  0.102,  0.102]),
#    'III': array([0.036, 0.036, 0.039, ..., 0.123, 0.123, 0.126]),
#    'AVR': array([-0.042, -0.045, -0.045, ..., -0.066, -0.069, -0.072]),
#    'AVL': array([ 0.027,  0.027,  0.03 , ..., -0.045, -0.042, -0.039]),
#    'AVF': array([0.012, 0.012, 0.012, ..., 0.114, 0.114, 0.114]),
#    'V1': array([0.054, 0.057, 0.057, ..., 0.021, 0.021, 0.021]),
#    'V2': array([0.081, 0.081, 0.081, ..., 0.015, 0.015, 0.015]),
#    'V3': array([0.063, 0.066, 0.066, ..., 0.15 , 0.15 , 0.15 ]),
#    'V4': array([0.021, 0.024, 0.024, ..., 0.141, 0.141, 0.141]),
#    'V5': array([-0.021, -0.018, -0.021, ...,  0.111,  0.111,  0.111]),
#    'V6': array([-0.045, -0.045, -0.045, ...,  0.075,  0.075,  0.075])},
#   'P63': {'I': array([-0.048, -0.045, -0.042, ..., -0.015, -0.012, -0.012]),
#    'II': array([-0.03 , -0.03 , -0.027, ...,  0.102,  0.099,  0.096]),
#    'III': array([0.018, 0.015, 0.012, ..., 0.12 , 0.114, 0.108]),
#    'AVR': array([-0.033, -0.03 , -0.03 , ..., -0.069, -0.063, -0.06 ]),
#    'AVL': array([ 0.039,  0.036,  0.036, ..., -0.042, -0.042, -0.042]),
#    'AVF': array([-0.003, -0.006, -0.006, ...,  0.111,  0.108,  0.102]),
#    'V1': array([0.054, 0.054, 0.054, ..., 0.015, 0.015, 0.012]),
#    'V2': array([0.078, 0.075, 0.075, ..., 0.024, 0.021, 0.021]),
#    'V3': array([0.06 , 0.06 , 0.06 , ..., 0.159, 0.156, 0.156]),
#    'V4': array([0.018, 0.018, 0.018, ..., 0.15 , 0.147, 0.141]),
#    'V5': array([-0.015, -0.018, -0.018, ...,  0.123,  0.12 ,  0.114]),
#    'V6': array([-0.039, -0.039, -0.039, ...,  0.087,  0.084,  0.078])},
#   'P5': {'I': array([0.195, 0.204, 0.213, ..., 0.021, 0.024, 0.027]),
#    'II': array([0.306, 0.321, 0.342, ..., 0.159, 0.159, 0.156]),
#    'III': array([0.108, 0.114, 0.123, ..., 0.138, 0.132, 0.129]),
#    'AVR': array([ 0.042,  0.042,  0.045, ..., -0.057, -0.051, -0.051]),
#    'AVL': array([-0.246, -0.258, -0.273, ..., -0.09 , -0.09 , -0.093]),
#    'AVF': array([0.207, 0.216, 0.231, ..., 0.147, 0.144, 0.144]),
#    'V1': array([-0.219, -0.231, -0.24 , ...,  0.   ,  0.   ,  0.   ]),
#    'V2': array([-0.015, -0.021, -0.027, ...,  0.033,  0.033,  0.03 ]),
#    'V3': array([0.063, 0.066, 0.069, ..., 0.156, 0.153, 0.15 ]),
#    'V4': array([0.249, 0.264, 0.282, ..., 0.174, 0.174, 0.171]),
#    'V5': array([0.351, 0.375, 0.399, ..., 0.177, 0.174, 0.171]),
#    'V6': array([0.36 , 0.378, 0.399, ..., 0.147, 0.144, 0.144])},
#   'P90': {'I': array([ 0.018,  0.024,  0.024, ..., -0.024, -0.021, -0.018]),
#    'II': array([-0.003,  0.   ,  0.   , ...,  0.102,  0.102,  0.102]),
#    'III': array([-0.021, -0.024, -0.024, ...,  0.132,  0.126,  0.123]),
#    'AVR': array([ 0.018,  0.024,  0.024, ..., -0.078, -0.072, -0.069]),
#    'AVL': array([-0.006, -0.009, -0.012, ..., -0.039, -0.042, -0.042]),
#    'AVF': array([-0.012, -0.012, -0.012, ...,  0.117,  0.114,  0.111]),
#    'V1': array([-0.024, -0.027, -0.027, ...,  0.021,  0.018,  0.018]),
#    'V2': array([-0.003, -0.006, -0.009, ...,  0.015,  0.012,  0.012]),
#    'V3': array([0.018, 0.018, 0.015, ..., 0.165, 0.165, 0.162]),
#    'V4': array([0.045, 0.045, 0.042, ..., 0.156, 0.153, 0.15 ]),
#    'V5': array([0.057, 0.054, 0.051, ..., 0.117, 0.117, 0.114]),
#    'V6': array([0.048, 0.048, 0.045, ..., 0.078, 0.078, 0.078])},
#   'P23': {'I': array([0.501, 0.504, 0.51 , ..., 0.009, 0.006, 0.006]),
#    'II': array([ 0.543,  0.516,  0.486, ..., -0.003, -0.003, -0.003]),
#    'III': array([ 0.036,  0.006, -0.024, ..., -0.012, -0.012, -0.012]),
#    'AVR': array([0.231, 0.249, 0.267, ..., 0.009, 0.009, 0.009]),
#    'AVL': array([-0.519, -0.507, -0.495, ..., -0.003,  0.   ,  0.   ]),
#    'AVF': array([ 0.291,  0.261,  0.231, ..., -0.006, -0.006, -0.009]),
#    'V1': array([-0.54 , -0.543, -0.537, ..., -0.021, -0.021, -0.021]),
#    'V2': array([-0.216, -0.234, -0.231, ..., -0.015, -0.015, -0.012]),
#    'V3': array([-0.03 , -0.09 , -0.141, ..., -0.024, -0.024, -0.024]),
#    'V4': array([0.633, 0.57 , 0.504, ..., 0.003, 0.003, 0.003]),
#    'V5': array([1.089, 1.041, 0.984, ..., 0.024, 0.024, 0.024]),
#    'V6': array([1.161, 1.14 , 1.104, ..., 0.024, 0.024, 0.024])},
#   'P15': {'I': array([-0.018, -0.021, -0.018, ...,  0.036,  0.03 ,  0.024]),
#    'II': array([-0.042, -0.039, -0.036, ...,  0.084,  0.087,  0.09 ]),
#    'III': array([-0.021, -0.018, -0.018, ...,  0.048,  0.057,  0.066]),
#    'AVR': array([ 0.   ,  0.   ,  0.   , ..., -0.006, -0.012, -0.018]),
#    'AVL': array([ 0.03 ,  0.03 ,  0.03 , ..., -0.063, -0.06 , -0.06 ]),
#    'AVF': array([-0.033, -0.03 , -0.027, ...,  0.066,  0.072,  0.078]),
#    'V1': array([ 0.018,  0.018,  0.021, ..., -0.048, -0.045, -0.042]),
#    'V2': array([-0.06 , -0.057, -0.054, ...,  0.042,  0.045,  0.048]),
#    'V3': array([-0.06 , -0.06 , -0.057, ...,  0.057,  0.06 ,  0.057]),
#    'V4': array([-0.093, -0.09 , -0.087, ...,  0.168,  0.168,  0.171]),
#    'V5': array([-0.093, -0.09 , -0.09 , ...,  0.159,  0.156,  0.159]),
#    'V6': array([-0.075, -0.072, -0.072, ...,  0.102,  0.102,  0.108])},
#   'P62': {'I': array([-0.03 , -0.033, -0.036, ..., -0.009, -0.009, -0.012]),
#    'II': array([-0.003, -0.003, -0.003, ...,  0.096,  0.096,  0.096]),
#    'III': array([0.024, 0.027, 0.033, ..., 0.108, 0.108, 0.108]),
#    'AVR': array([-0.027, -0.03 , -0.033, ..., -0.057, -0.06 , -0.063]),
#    'AVL': array([ 0.018,  0.018,  0.021, ..., -0.042, -0.042, -0.039]),
#    'AVF': array([0.009, 0.012, 0.012, ..., 0.102, 0.102, 0.102]),
#    'V1': array([0.054, 0.054, 0.054, ..., 0.015, 0.012, 0.009]),
#    'V2': array([0.078, 0.078, 0.081, ..., 0.024, 0.024, 0.024]),
#    'V3': array([0.078, 0.078, 0.078, ..., 0.138, 0.138, 0.135]),
#    'V4': array([0.012, 0.012, 0.015, ..., 0.141, 0.138, 0.138]),
#    'V5': array([-0.036, -0.036, -0.033, ...,  0.105,  0.105,  0.105]),
#    'V6': array([-0.063, -0.063, -0.06 , ...,  0.075,  0.075,  0.075])},
#   'P121': {'I': array([ 0.024,  0.027,  0.027, ..., -0.021, -0.027, -0.03 ]),
#    'II': array([0.033, 0.039, 0.042, ..., 0.135, 0.135, 0.135]),
#    'III': array([0.006, 0.009, 0.015, ..., 0.159, 0.162, 0.168]),
#    'AVR': array([ 0.009,  0.006,  0.006, ..., -0.09 , -0.093, -0.099]),
#    'AVL': array([-0.03 , -0.033, -0.036, ..., -0.057, -0.054, -0.054]),
#    'AVF': array([0.021, 0.024, 0.03 , ..., 0.147, 0.15 , 0.153]),
#    'V1': array([-0.033, -0.027, -0.024, ...,  0.012,  0.012,  0.015]),
#    'V2': array([-0.012, -0.006, -0.003, ...,  0.015,  0.015,  0.015]),
#    'V3': array([0.   , 0.006, 0.012, ..., 0.174, 0.174, 0.177]),
#    'V4': array([0.009, 0.015, 0.021, ..., 0.168, 0.168, 0.168]),
#    'V5': array([0.   , 0.006, 0.012, ..., 0.138, 0.141, 0.144]),
#    'V6': array([0.   , 0.009, 0.015, ..., 0.102, 0.105, 0.108])},
#   'P14': {'I': array([-0.081, -0.078, -0.072, ..., -0.036, -0.036, -0.03 ]),
#    'II': array([0.027, 0.027, 0.027, ..., 0.078, 0.075, 0.075]),
#    'III': array([0.108, 0.105, 0.099, ..., 0.117, 0.111, 0.108]),
#    'AVR': array([-0.096, -0.093, -0.087, ..., -0.078, -0.075, -0.069]),
#    'AVL': array([ 0.024,  0.024,  0.021, ..., -0.018, -0.021, -0.021]),
#    'AVF': array([0.069, 0.066, 0.063, ..., 0.099, 0.096, 0.093]),
#    'V1': array([0.099, 0.099, 0.096, ..., 0.009, 0.006, 0.006]),
#    'V2': array([ 0.129,  0.129,  0.126, ..., -0.012, -0.012, -0.012]),
#    'V3': array([0.213, 0.21 , 0.207, ..., 0.078, 0.078, 0.075]),
#    'V4': array([0.132, 0.129, 0.126, ..., 0.084, 0.084, 0.081]),
#    'V5': array([0.042, 0.039, 0.036, ..., 0.078, 0.078, 0.075]),
#    'V6': array([-0.009, -0.012, -0.015, ...,  0.048,  0.048,  0.048])},
#   'P1': {'I': array([-0.054, -0.06 , -0.066, ..., -0.003, -0.009, -0.012]),
#    'II': array([-0.015, -0.015, -0.018, ...,  0.093,  0.093,  0.093]),
#    'III': array([0.036, 0.042, 0.045, ..., 0.102, 0.102, 0.108]),
#    'AVR': array([-0.045, -0.051, -0.054, ..., -0.054, -0.057, -0.06 ]),
#    'AVL': array([ 0.033,  0.036,  0.042, ..., -0.045, -0.039, -0.039]),
#    'AVF': array([0.009, 0.012, 0.012, ..., 0.099, 0.099, 0.099]),
#    'V1': array([0.09 , 0.09 , 0.087, ..., 0.003, 0.006, 0.009]),
#    'V2': array([0.102, 0.105, 0.102, ..., 0.003, 0.006, 0.009]),
#    'V3': array([0.228, 0.231, 0.228, ..., 0.078, 0.078, 0.081]),
#    'V4': array([0.129, 0.129, 0.126, ..., 0.09 , 0.09 , 0.09 ]),
#    'V5': array([0.033, 0.033, 0.03 , ..., 0.081, 0.084, 0.087]),
#    'V6': array([-0.018, -0.018, -0.018, ...,  0.057,  0.057,  0.06 ])},
#   'P72': {'I': array([-0.03 , -0.033, -0.039, ..., -0.009, -0.012, -0.009]),
#    'II': array([-0.024, -0.024, -0.024, ...,  0.111,  0.114,  0.114]),
#    'III': array([0.006, 0.009, 0.015, ..., 0.126, 0.126, 0.129]),
#    'AVR': array([-0.021, -0.021, -0.027, ..., -0.066, -0.069, -0.069]),
#    'AVL': array([ 0.027,  0.027,  0.03 , ..., -0.051, -0.051, -0.051]),
#    'AVF': array([-0.006, -0.006, -0.003, ...,  0.117,  0.12 ,  0.12 ]),
#    'V1': array([0.042, 0.045, 0.048, ..., 0.012, 0.012, 0.012]),
#    'V2': array([0.063, 0.066, 0.069, ..., 0.021, 0.021, 0.021]),
#    'V3': array([0.057, 0.06 , 0.063, ..., 0.156, 0.159, 0.159]),
#    'V4': array([0.006, 0.009, 0.012, ..., 0.15 , 0.15 , 0.15 ]),
#    'V5': array([-0.036, -0.033, -0.033, ...,  0.123,  0.123,  0.123]),
#    'V6': array([-0.069, -0.066, -0.066, ...,  0.087,  0.09 ,  0.09 ])},
#   'P106': {'I': array([ 0.006,  0.012,  0.018, ..., -0.021, -0.021, -0.024]),
#    'II': array([-0.012, -0.012, -0.012, ...,  0.111,  0.108,  0.105]),
#    'III': array([-0.021, -0.024, -0.03 , ...,  0.132,  0.132,  0.132]),
#    'AVR': array([ 0.015,  0.018,  0.021, ..., -0.075, -0.075, -0.078]),
#    'AVL': array([ 0.   ,  0.   ,  0.   , ..., -0.045, -0.042, -0.042]),
#    'AVF': array([-0.018, -0.018, -0.021, ...,  0.123,  0.12 ,  0.12 ]),
#    'V1': array([-0.021, -0.021, -0.021, ...,  0.015,  0.015,  0.012]),
#    'V2': array([-0.006, -0.003, -0.003, ..., -0.003, -0.003, -0.006]),
#    'V3': array([0.006, 0.006, 0.006, ..., 0.144, 0.144, 0.144]),
#    'V4': array([0.03 , 0.03 , 0.03 , ..., 0.141, 0.141, 0.141]),
#    'V5': array([0.039, 0.039, 0.039, ..., 0.111, 0.111, 0.111]),
#    'V6': array([0.039, 0.039, 0.036, ..., 0.078, 0.078, 0.075])},
#   'P64': {'I': array([-0.039, -0.033, -0.027, ..., -0.021, -0.018, -0.012]),
#    'II': array([-0.015, -0.015, -0.015, ...,  0.102,  0.105,  0.105]),
#    'III': array([0.021, 0.015, 0.012, ..., 0.129, 0.126, 0.12 ]),
#    'AVR': array([-0.027, -0.024, -0.018, ..., -0.075, -0.072, -0.066]),
#    'AVL': array([ 0.027,  0.024,  0.021, ..., -0.039, -0.042, -0.045]),
#    'AVF': array([0.   , 0.   , 0.   , ..., 0.114, 0.114, 0.111]),
#    'V1': array([0.057, 0.054, 0.054, ..., 0.024, 0.021, 0.021]),
#    'V2': array([0.078, 0.078, 0.075, ..., 0.048, 0.048, 0.045]),
#    'V3': array([0.069, 0.066, 0.066, ..., 0.171, 0.174, 0.174]),
#    'V4': array([0.015, 0.012, 0.009, ..., 0.174, 0.177, 0.177]),
#    'V5': array([-0.024, -0.027, -0.027, ...,  0.141,  0.141,  0.141]),
#    'V6': array([-0.057, -0.06 , -0.06 , ...,  0.099,  0.099,  0.099])},
#   'P126': {'I': array([ 0.141,  0.135,  0.132, ..., -0.093, -0.09 , -0.087]),
#    'II': array([ 0.111,  0.111,  0.105, ..., -0.024, -0.021, -0.021]),
#    'III': array([-0.027, -0.024, -0.024, ...,  0.066,  0.066,  0.066]),
#    'AVR': array([ 0.084,  0.081,  0.078, ..., -0.078, -0.078, -0.075]),
#    'AVL': array([-0.126, -0.123, -0.12 , ...,  0.057,  0.054,  0.054]),
#    'AVF': array([0.039, 0.042, 0.042, ..., 0.021, 0.021, 0.021]),
#    'V1': array([-0.219, -0.216, -0.213, ...,  0.096,  0.096,  0.096]),
#    'V2': array([-0.021, -0.021, -0.021, ...,  0.012,  0.012,  0.012]),
#    'V3': array([-0.057, -0.054, -0.051, ...,  0.066,  0.066,  0.063]),
#    'V4': array([0.087, 0.087, 0.084, ..., 0.   , 0.   , 0.   ]),
#    'V5': array([ 0.165,  0.162,  0.159, ..., -0.036, -0.036, -0.036]),
#    'V6': array([ 0.186,  0.183,  0.177, ..., -0.06 , -0.06 , -0.06 ])},
#   'P113': {'I': array([ 0.   ,  0.   , -0.003, ..., -0.021, -0.024, -0.027]),
#    'II': array([0.003, 0.003, 0.   , ..., 0.141, 0.141, 0.144]),
#    'III': array([0.003, 0.006, 0.006, ..., 0.168, 0.171, 0.174]),
#    'AVR': array([-0.003, -0.003, -0.006, ..., -0.093, -0.099, -0.099]),
#    'AVL': array([ 0.   ,  0.   ,  0.   , ..., -0.057, -0.057, -0.057]),
#    'AVF': array([0.006, 0.006, 0.003, ..., 0.153, 0.156, 0.159]),
#    'V1': array([-0.015, -0.015, -0.018, ...,  0.027,  0.03 ,  0.033]),
#    'V2': array([-0.006, -0.006, -0.003, ...,  0.06 ,  0.06 ,  0.063]),
#    'V3': array([0.015, 0.018, 0.018, ..., 0.195, 0.195, 0.195]),
#    'V4': array([0.045, 0.048, 0.048, ..., 0.186, 0.186, 0.186]),
#    'V5': array([0.048, 0.048, 0.051, ..., 0.15 , 0.153, 0.153]),
#    'V6': array([0.039, 0.039, 0.042, ..., 0.114, 0.117, 0.117])},
#   'P130': {'I': array([0.045, 0.045, 0.045, ..., 0.009, 0.009, 0.009]),
#    'II': array([0.09 , 0.09 , 0.09 , ..., 0.114, 0.12 , 0.126]),
#    'III': array([0.045, 0.045, 0.045, ..., 0.105, 0.111, 0.117]),
#    'AVR': array([ 0.   ,  0.   ,  0.   , ..., -0.048, -0.048, -0.054]),
#    'AVL': array([-0.066, -0.069, -0.066, ..., -0.063, -0.063, -0.066]),
#    'AVF': array([0.069, 0.069, 0.066, ..., 0.111, 0.114, 0.12 ]),
#    'V1': array([ 0.027,  0.027,  0.027, ..., -0.003,  0.   ,  0.   ]),
#    'V2': array([0.06 , 0.063, 0.066, ..., 0.051, 0.054, 0.057]),
#    'V3': array([0.069, 0.069, 0.072, ..., 0.198, 0.201, 0.204]),
#    'V4': array([0.075, 0.075, 0.078, ..., 0.225, 0.225, 0.228]),
#    'V5': array([0.075, 0.075, 0.075, ..., 0.183, 0.186, 0.189]),
#    'V6': array([0.063, 0.066, 0.066, ..., 0.159, 0.162, 0.162])},
#   'P134': {'I': array([0.018, 0.012, 0.006, ..., 0.   , 0.006, 0.006]),
#    'II': array([-0.027, -0.027, -0.027, ...,  0.159,  0.162,  0.159]),
#    'III': array([-0.048, -0.042, -0.036, ...,  0.156,  0.153,  0.153]),
#    'AVR': array([ 0.033,  0.027,  0.021, ..., -0.078, -0.072, -0.069]),
#    'AVL': array([ 0.003,  0.006,  0.009, ..., -0.081, -0.084, -0.084]),
#    'AVF': array([-0.039, -0.036, -0.03 , ...,  0.159,  0.159,  0.156]),
#    'V1': array([-0.006, -0.003,  0.   , ...,  0.   ,  0.   ,  0.   ]),
#    'V2': array([-0.012, -0.012, -0.009, ...,  0.018,  0.015,  0.015]),
#    'V3': array([0.018, 0.018, 0.021, ..., 0.201, 0.198, 0.198]),
#    'V4': array([0.033, 0.036, 0.039, ..., 0.213, 0.21 , 0.21 ]),
#    'V5': array([0.027, 0.03 , 0.033, ..., 0.171, 0.168, 0.168]),
#    'V6': array([0.015, 0.018, 0.018, ..., 0.138, 0.135, 0.135])},
#   'P131': {'I': array([-0.105, -0.105, -0.108, ...,  0.018,  0.018,  0.012]),
#    'II': array([-0.321, -0.342, -0.366, ...,  0.189,  0.186,  0.183]),
#    'III': array([-0.216, -0.24 , -0.264, ...,  0.168,  0.168,  0.168]),
#    'AVR': array([ 0.057,  0.069,  0.081, ..., -0.075, -0.075, -0.078]),
#    'AVL': array([ 0.213,  0.222,  0.231, ..., -0.105, -0.102, -0.099]),
#    'AVF': array([-0.267, -0.291, -0.315, ...,  0.18 ,  0.177,  0.174]),
#    'V1': array([0.087, 0.084, 0.081, ..., 0.003, 0.   , 0.   ]),
#    'V2': array([-0.222, -0.213, -0.201, ...,  0.069,  0.066,  0.066]),
#    'V3': array([-0.234, -0.279, -0.324, ...,  0.21 ,  0.207,  0.21 ]),
#    'V4': array([-0.378, -0.408, -0.435, ...,  0.213,  0.21 ,  0.213]),
#    'V5': array([-0.402, -0.423, -0.441, ...,  0.183,  0.183,  0.183]),
#    'V6': array([-0.375, -0.384, -0.39 , ...,  0.144,  0.141,  0.141])},
#   'P34': {'I': array([-0.063, -0.063, -0.063, ...,  0.009,  0.012,  0.015]),
#    'II': array([-0.03 , -0.03 , -0.03 , ...,  0.003,  0.003,  0.003]),
#    'III': array([ 0.033,  0.03 ,  0.03 , ..., -0.006, -0.009, -0.009]),
#    'AVR': array([-0.048, -0.045, -0.045, ...,  0.006,  0.009,  0.012]),
#    'AVL': array([ 0.045,  0.045,  0.045, ..., -0.006, -0.009, -0.009]),
#    'AVF': array([ 0.   ,  0.   ,  0.   , ...,  0.   ,  0.   , -0.003]),
#    'V1': array([ 0.096,  0.096,  0.096, ..., -0.009, -0.012, -0.012]),
#    'V2': array([0.072, 0.072, 0.075, ..., 0.   , 0.   , 0.   ]),
#    'V3': array([ 0.09 ,  0.09 ,  0.09 , ..., -0.012, -0.009, -0.012]),
#    'V4': array([0.021, 0.021, 0.021, ..., 0.021, 0.021, 0.018]),
#    'V5': array([-0.042, -0.042, -0.039, ...,  0.036,  0.036,  0.033]),
#    'V6': array([-0.075, -0.075, -0.075, ...,  0.036,  0.036,  0.033])},
#   'P59': {'I': array([-0.048, -0.048, -0.045, ..., -0.039, -0.036, -0.03 ]),
#    'II': array([-0.042, -0.042, -0.042, ...,  0.117,  0.117,  0.12 ]),
#    'III': array([0.009, 0.003, 0.003, ..., 0.159, 0.156, 0.15 ]),
#    'AVR': array([-0.03 , -0.027, -0.024, ..., -0.099, -0.096, -0.09 ]),
#    'AVL': array([ 0.045,  0.045,  0.045, ..., -0.039, -0.042, -0.045]),
#    'AVF': array([-0.015, -0.018, -0.018, ...,  0.138,  0.138,  0.135]),
#    'V1': array([0.066, 0.066, 0.066, ..., 0.006, 0.006, 0.009]),
#    'V2': array([0.078, 0.075, 0.072, ..., 0.009, 0.009, 0.009]),
#    'V3': array([0.048, 0.048, 0.045, ..., 0.135, 0.135, 0.138]),
#    'V4': array([ 0.   , -0.003, -0.003, ...,  0.135,  0.135,  0.141]),
#    'V5': array([-0.051, -0.054, -0.057, ...,  0.102,  0.102,  0.102]),
#    'V6': array([-0.072, -0.075, -0.075, ...,  0.066,  0.066,  0.066])},
#   'P101': {'I': array([-0.045, -0.042, -0.045, ..., -0.018, -0.012, -0.009]),
#    'II': array([-0.042, -0.042, -0.045, ...,  0.117,  0.117,  0.114]),
#    'III': array([0.003, 0.   , 0.   , ..., 0.138, 0.132, 0.126]),
#    'AVR': array([-0.024, -0.021, -0.021, ..., -0.078, -0.072, -0.069]),
#    'AVL': array([ 0.042,  0.042,  0.045, ..., -0.048, -0.051, -0.051]),
#    'AVF': array([-0.018, -0.021, -0.024, ...,  0.129,  0.126,  0.12 ]),
#    'V1': array([0.069, 0.069, 0.069, ..., 0.009, 0.006, 0.003]),
#    'V2': array([0.078, 0.075, 0.075, ..., 0.027, 0.027, 0.024]),
#    'V3': array([0.054, 0.051, 0.045, ..., 0.162, 0.159, 0.156]),
#    'V4': array([ 0.003,  0.   , -0.003, ...,  0.153,  0.15 ,  0.15 ]),
#    'V5': array([-0.042, -0.042, -0.045, ...,  0.135,  0.132,  0.132]),
#    'V6': array([-0.063, -0.066, -0.069, ...,  0.096,  0.093,  0.09 ])},
#   'P68': {'I': array([-0.006, -0.006, -0.003, ...,  0.006,  0.003,  0.003]),
#    'II': array([-0.027, -0.027, -0.027, ...,  0.009,  0.009,  0.012]),
#    'III': array([-0.021, -0.021, -0.021, ...,  0.   ,  0.003,  0.006]),
#    'AVR': array([0.006, 0.003, 0.006, ..., 0.   , 0.   , 0.   ]),
#    'AVL': array([ 0.015,  0.018,  0.015, ..., -0.006, -0.006, -0.006]),
#    'AVF': array([-0.024, -0.024, -0.024, ...,  0.006,  0.009,  0.009]),
#    'V1': array([-0.015, -0.015, -0.012, ..., -0.006, -0.003, -0.003]),
#    'V2': array([-0.033, -0.033, -0.033, ..., -0.003,  0.   ,  0.   ]),
#    'V3': array([-0.03 , -0.03 , -0.03 , ...,  0.012,  0.015,  0.015]),
#    'V4': array([-0.009, -0.009, -0.009, ...,  0.024,  0.027,  0.03 ]),
#    'V5': array([0.006, 0.006, 0.009, ..., 0.033, 0.036, 0.036]),
#    'V6': array([0.009, 0.009, 0.012, ..., 0.021, 0.024, 0.027])},
#   'P71': {'I': array([-0.051, -0.048, -0.045, ..., -0.018, -0.015, -0.009]),
#    'II': array([-0.021, -0.021, -0.018, ...,  0.108,  0.105,  0.105]),
#    'III': array([0.027, 0.027, 0.027, ..., 0.129, 0.123, 0.117]),
#    'AVR': array([-0.039, -0.036, -0.036, ..., -0.072, -0.069, -0.063]),
#    'AVL': array([ 0.036,  0.033,  0.033, ..., -0.045, -0.045, -0.048]),
#    'AVF': array([0.003, 0.003, 0.003, ..., 0.117, 0.114, 0.111]),
#    'V1': array([0.054, 0.051, 0.051, ..., 0.021, 0.021, 0.018]),
#    'V2': array([0.015, 0.015, 0.012, ..., 0.018, 0.015, 0.015]),
#    'V3': array([0.039, 0.039, 0.039, ..., 0.159, 0.156, 0.153]),
#    'V4': array([-0.063, -0.063, -0.063, ...,  0.156,  0.153,  0.153]),
#    'V5': array([-0.111, -0.111, -0.114, ...,  0.126,  0.123,  0.12 ]),
#    'V6': array([-0.12 , -0.123, -0.123, ...,  0.084,  0.081,  0.081])},
#   'P48': {'I': array([-0.06 , -0.063, -0.063, ..., -0.054, -0.057, -0.06 ]),
#    'II': array([-0.033, -0.03 , -0.03 , ..., -0.015, -0.015, -0.015]),
#    'III': array([0.024, 0.027, 0.03 , ..., 0.036, 0.039, 0.045]),
#    'AVR': array([-0.042, -0.045, -0.045, ..., -0.045, -0.048, -0.051]),
#    'AVL': array([0.045, 0.048, 0.048, ..., 0.036, 0.036, 0.039]),
#    'AVF': array([-0.003,  0.   ,  0.   , ...,  0.009,  0.012,  0.012]),
#    'V1': array([0.063, 0.066, 0.066, ..., 0.036, 0.036, 0.036]),
#    'V2': array([ 0.078,  0.081,  0.081, ..., -0.042, -0.039, -0.036]),
#    'V3': array([0.072, 0.072, 0.075, ..., 0.027, 0.03 , 0.033]),
#    'V4': array([0.003, 0.006, 0.009, ..., 0.   , 0.   , 0.   ]),
#    'V5': array([-0.048, -0.048, -0.045, ..., -0.024, -0.024, -0.021]),
#    'V6': array([-0.072, -0.069, -0.069, ..., -0.03 , -0.03 , -0.03 ])},
#   'P53': {'I': array([-0.045, -0.045, -0.045, ..., -0.006, -0.003, -0.003]),
#    'II': array([-0.042, -0.039, -0.039, ...,  0.042,  0.042,  0.045]),
#    'III': array([0.003, 0.003, 0.003, ..., 0.048, 0.045, 0.045]),
#    'AVR': array([-0.024, -0.024, -0.024, ..., -0.027, -0.024, -0.024]),
#    'AVL': array([ 0.045,  0.042,  0.042, ..., -0.018, -0.018, -0.018]),
#    'AVF': array([-0.018, -0.015, -0.015, ...,  0.045,  0.042,  0.042]),
#    'V1': array([0.054, 0.054, 0.054, ..., 0.027, 0.027, 0.027]),
#    'V2': array([0.069, 0.069, 0.069, ..., 0.048, 0.045, 0.039]),
#    'V3': array([0.06 , 0.06 , 0.063, ..., 0.129, 0.129, 0.129]),
#    'V4': array([0.   , 0.   , 0.   , ..., 0.126, 0.126, 0.126]),
#    'V5': array([-0.057, -0.054, -0.051, ...,  0.081,  0.081,  0.081]),
#    'V6': array([-0.09 , -0.09 , -0.09 , ...,  0.042,  0.039,  0.039])},
#   'P22': {'I': array([-0.027, -0.03 , -0.033, ..., -0.024, -0.027, -0.033]),
#    'II': array([-0.006, -0.003, -0.003, ...,  0.093,  0.093,  0.093]),
#    'III': array([0.021, 0.024, 0.03 , ..., 0.117, 0.12 , 0.126]),
#    'AVR': array([-0.024, -0.027, -0.03 , ..., -0.069, -0.075, -0.081]),
#    'AVL': array([ 0.018,  0.018,  0.018, ..., -0.033, -0.033, -0.03 ]),
#    'AVF': array([0.006, 0.009, 0.012, ..., 0.105, 0.105, 0.108]),
#    'V1': array([0.036, 0.036, 0.036, ..., 0.021, 0.021, 0.021]),
#    'V2': array([ 0.015,  0.018,  0.018, ..., -0.009, -0.009, -0.009]),
#    'V3': array([0.045, 0.045, 0.045, ..., 0.096, 0.099, 0.102]),
#    'V4': array([-0.054, -0.054, -0.051, ...,  0.087,  0.087,  0.09 ]),
#    'V5': array([-0.123, -0.117, -0.114, ...,  0.06 ,  0.063,  0.066]),
#    'V6': array([-0.129, -0.123, -0.12 , ...,  0.03 ,  0.033,  0.033])},
#   'P81': {'I': array([-0.036, -0.036, -0.033, ..., -0.015, -0.015, -0.015]),
#    'II': array([-0.042, -0.042, -0.045, ...,  0.117,  0.117,  0.117]),
#    'III': array([-0.003, -0.006, -0.012, ...,  0.135,  0.135,  0.135]),
#    'AVR': array([-0.012, -0.012, -0.009, ..., -0.075, -0.075, -0.075]),
#    'AVL': array([ 0.039,  0.039,  0.039, ..., -0.051, -0.051, -0.051]),
#    'AVF': array([-0.024, -0.024, -0.027, ...,  0.126,  0.126,  0.123]),
#    'V1': array([0.03 , 0.027, 0.027, ..., 0.027, 0.027, 0.027]),
#    'V2': array([0.054, 0.054, 0.054, ..., 0.039, 0.039, 0.036]),
#    'V3': array([0.039, 0.039, 0.039, ..., 0.18 , 0.18 , 0.177]),
#    'V4': array([-0.024, -0.024, -0.027, ...,  0.183,  0.18 ,  0.177]),
#    'V5': array([-0.102, -0.102, -0.102, ...,  0.144,  0.144,  0.141]),
#    'V6': array([-0.108, -0.111, -0.111, ...,  0.105,  0.108,  0.105])},
#   'P45': {'I': array([0.009, 0.009, 0.012, ..., 0.258, 0.267, 0.279]),
#    'II': array([0.   , 0.   , 0.   , ..., 1.329, 1.341, 1.362]),
#    'III': array([-0.009, -0.012, -0.015, ...,  1.068,  1.071,  1.083]),
#    'AVR': array([ 0.009,  0.012,  0.012, ..., -0.42 , -0.42 , -0.42 ]),
#    'AVL': array([-0.003, -0.003, -0.006, ..., -0.795, -0.807, -0.825]),
#    'AVF': array([-0.006, -0.009, -0.009, ...,  1.206,  1.218,  1.233]),
#    'V1': array([-0.009, -0.012, -0.009, ..., -0.102, -0.12 , -0.144]),
#    'V2': array([0.003, 0.   , 0.   , ..., 0.492, 0.438, 0.381]),
#    'V3': array([0.003, 0.003, 0.   , ..., 1.119, 1.11 , 1.104]),
#    'V4': array([0.003, 0.   , 0.   , ..., 1.425, 1.44 , 1.461]),
#    'V5': array([0.003, 0.   , 0.   , ..., 1.44 , 1.473, 1.515]),
#    'V6': array([0.006, 0.   , 0.   , ..., 1.323, 1.356, 1.398])},
#   'P120': {'I': array([ 0.003,  0.003,  0.003, ..., -0.027, -0.024, -0.021]),
#    'II': array([0.006, 0.009, 0.012, ..., 0.129, 0.132, 0.135]),
#    'III': array([0.003, 0.006, 0.009, ..., 0.159, 0.159, 0.162]),
#    'AVR': array([ 0.   ,  0.   , -0.003, ..., -0.093, -0.093, -0.093]),
#    'AVL': array([-0.003, -0.006, -0.006, ..., -0.051, -0.054, -0.054]),
#    'AVF': array([0.006, 0.009, 0.012, ..., 0.144, 0.147, 0.147]),
#    'V1': array([-0.033, -0.03 , -0.027, ...,  0.042,  0.042,  0.042]),
#    'V2': array([-0.009, -0.006, -0.003, ...,  0.063,  0.063,  0.066]),
#    'V3': array([-0.003, -0.003,  0.   , ...,  0.216,  0.216,  0.219]),
#    'V4': array([0.042, 0.042, 0.042, ..., 0.201, 0.201, 0.204]),
#    'V5': array([0.048, 0.051, 0.054, ..., 0.165, 0.165, 0.168]),
#    'V6': array([0.045, 0.048, 0.051, ..., 0.111, 0.111, 0.114])},
#   'P55': {'I': array([ 0.045,  0.045,  0.042, ..., -0.012, -0.015, -0.018]),
#    'II': array([0.042, 0.039, 0.036, ..., 0.099, 0.099, 0.099]),
#    'III': array([-0.003, -0.003, -0.006, ...,  0.114,  0.117,  0.12 ]),
#    'AVR': array([ 0.024,  0.024,  0.024, ..., -0.063, -0.066, -0.069]),
#    'AVL': array([-0.045, -0.042, -0.039, ..., -0.042, -0.042, -0.039]),
#    'AVF': array([0.018, 0.018, 0.015, ..., 0.108, 0.108, 0.108]),
#    'V1': array([0.027, 0.024, 0.021, ..., 0.015, 0.015, 0.018]),
#    'V2': array([0.09 , 0.087, 0.087, ..., 0.009, 0.012, 0.012]),
#    'V3': array([0.075, 0.072, 0.069, ..., 0.144, 0.147, 0.147]),
#    'V4': array([0.066, 0.066, 0.063, ..., 0.141, 0.141, 0.141]),
#    'V5': array([0.06 , 0.06 , 0.057, ..., 0.114, 0.117, 0.114]),
#    'V6': array([0.051, 0.051, 0.048, ..., 0.078, 0.081, 0.078])},
#   'P74': {'I': array([ 0.033,  0.033,  0.033, ..., -0.006, -0.003,  0.   ]),
#    'II': array([0.024, 0.024, 0.021, ..., 0.105, 0.102, 0.102]),
#    'III': array([-0.006, -0.009, -0.009, ...,  0.111,  0.108,  0.105]),
#    'AVR': array([ 0.021,  0.021,  0.021, ..., -0.057, -0.054, -0.054]),
#    'AVL': array([-0.03 , -0.03 , -0.027, ..., -0.048, -0.051, -0.051]),
#    'AVF': array([0.009, 0.006, 0.006, ..., 0.108, 0.105, 0.105]),
#    'V1': array([-0.033, -0.036, -0.036, ...,  0.027,  0.027,  0.024]),
#    'V2': array([0.003, 0.003, 0.   , ..., 0.03 , 0.03 , 0.027]),
#    'V3': array([0.024, 0.021, 0.021, ..., 0.162, 0.162, 0.159]),
#    'V4': array([0.045, 0.045, 0.042, ..., 0.15 , 0.15 , 0.147]),
#    'V5': array([0.039, 0.039, 0.036, ..., 0.126, 0.123, 0.123]),
#    'V6': array([0.036, 0.033, 0.033, ..., 0.09 , 0.087, 0.084])},
#   'P108': {'I': array([-0.111, -0.108, -0.108, ..., -0.006, -0.009, -0.012]),
#    'II': array([-0.108, -0.132, -0.15 , ...,  0.126,  0.129,  0.132]),
#    'III': array([ 0.003, -0.018, -0.039, ...,  0.135,  0.141,  0.144]),
#    'AVR': array([-0.06 , -0.045, -0.033, ..., -0.072, -0.075, -0.078]),
#    'AVL': array([ 0.111,  0.123,  0.132, ..., -0.06 , -0.057, -0.06 ]),
#    'AVF': array([-0.051, -0.075, -0.096, ...,  0.132,  0.135,  0.138]),
#    'V1': array([0.114, 0.102, 0.09 , ..., 0.003, 0.003, 0.003]),
#    'V2': array([-0.159, -0.162, -0.165, ...,  0.063,  0.063,  0.066]),
#    'V3': array([0.153, 0.105, 0.057, ..., 0.201, 0.201, 0.201]),
#    'V4': array([ 0.   , -0.045, -0.084, ...,  0.213,  0.213,  0.213]),
#    'V5': array([-0.12 , -0.147, -0.171, ...,  0.165,  0.168,  0.168]),
#    'V6': array([-0.192, -0.21 , -0.222, ...,  0.129,  0.132,  0.132])},
#   'P12': {'I': array([0.033, 0.033, 0.03 , ..., 0.027, 0.03 , 0.033]),
#    'II': array([-0.012, -0.009, -0.006, ..., -0.042, -0.039, -0.033]),
#    'III': array([-0.051, -0.048, -0.042, ..., -0.069, -0.069, -0.069]),
#    'AVR': array([0.039, 0.039, 0.036, ..., 0.048, 0.051, 0.051]),
#    'AVL': array([-0.009, -0.009, -0.009, ...,  0.006,  0.003,  0.   ]),
#    'AVF': array([-0.03 , -0.027, -0.024, ..., -0.054, -0.054, -0.051]),
#    'V1': array([-0.054, -0.054, -0.054, ..., -0.03 , -0.03 , -0.03 ]),
#    'V2': array([-0.045, -0.045, -0.045, ..., -0.021, -0.021, -0.021]),
#    'V3': array([-0.078, -0.075, -0.072, ..., -0.105, -0.105, -0.105]),
#    'V4': array([-0.03 , -0.027, -0.021, ..., -0.066, -0.066, -0.063]),
#    'V5': array([ 0.015,  0.018,  0.024, ..., -0.033, -0.033, -0.03 ]),
#    'V6': array([ 0.024,  0.027,  0.03 , ..., -0.006, -0.006, -0.006])},
#   'P117': {'I': array([ 0.018,  0.018,  0.015, ..., -0.015, -0.009, -0.006]),
#    'II': array([0.021, 0.018, 0.012, ..., 0.144, 0.147, 0.144]),
#    'III': array([ 0.   ,  0.   , -0.003, ...,  0.162,  0.156,  0.153]),
#    'AVR': array([ 0.006,  0.009,  0.009, ..., -0.09 , -0.084, -0.081]),
#    'AVL': array([-0.018, -0.018, -0.012, ..., -0.063, -0.069, -0.069]),
#    'AVF': array([0.009, 0.006, 0.003, ..., 0.153, 0.153, 0.15 ]),
#    'V1': array([-0.024, -0.024, -0.024, ...,  0.024,  0.024,  0.021]),
#    'V2': array([-0.003, -0.003, -0.003, ...,  0.045,  0.045,  0.042]),
#    'V3': array([0.024, 0.021, 0.021, ..., 0.201, 0.198, 0.195]),
#    'V4': array([0.045, 0.045, 0.042, ..., 0.198, 0.198, 0.195]),
#    'V5': array([0.048, 0.048, 0.045, ..., 0.156, 0.153, 0.15 ]),
#    'V6': array([0.039, 0.039, 0.036, ..., 0.114, 0.114, 0.111])},
#   'P39': {'I': array([ 0.051,  0.057,  0.063, ..., -0.042, -0.039, -0.036]),
#    'II': array([0.042, 0.042, 0.045, ..., 0.063, 0.063, 0.063]),
#    'III': array([-0.009, -0.015, -0.018, ...,  0.108,  0.105,  0.102]),
#    'AVR': array([ 0.03 ,  0.036,  0.042, ..., -0.075, -0.072, -0.069]),
#    'AVL': array([-0.048, -0.051, -0.054, ..., -0.009, -0.012, -0.015]),
#    'AVF': array([0.015, 0.012, 0.009, ..., 0.087, 0.084, 0.084]),
#    'V1': array([-0.06 , -0.063, -0.066, ...,  0.033,  0.033,  0.03 ]),
#    'V2': array([-0.009, -0.006, -0.006, ...,  0.003,  0.   ,  0.   ]),
#    'V3': array([-0.003, -0.003, -0.003, ...,  0.12 ,  0.12 ,  0.12 ]),
#    'V4': array([0.021, 0.024, 0.024, ..., 0.096, 0.093, 0.093]),
#    'V5': array([0.036, 0.039, 0.039, ..., 0.075, 0.075, 0.072]),
#    'V6': array([0.048, 0.051, 0.051, ..., 0.048, 0.048, 0.045])},
#   'P37': {'I': array([-0.051, -0.054, -0.057, ..., -0.009, -0.012, -0.015]),
#    'II': array([-0.039, -0.039, -0.039, ...,  0.093,  0.093,  0.096]),
#    'III': array([0.012, 0.015, 0.018, ..., 0.108, 0.111, 0.114]),
#    'AVR': array([-0.033, -0.036, -0.039, ..., -0.06 , -0.063, -0.066]),
#    'AVL': array([ 0.045,  0.048,  0.048, ..., -0.042, -0.039, -0.039]),
#    'AVF': array([-0.012, -0.009, -0.009, ...,  0.099,  0.102,  0.105]),
#    'V1': array([0.084, 0.087, 0.087, ..., 0.024, 0.027, 0.027]),
#    'V2': array([0.093, 0.096, 0.099, ..., 0.027, 0.03 , 0.033]),
#    'V3': array([0.081, 0.081, 0.081, ..., 0.144, 0.147, 0.147]),
#    'V4': array([0.03 , 0.03 , 0.03 , ..., 0.144, 0.147, 0.15 ]),
#    'V5': array([-0.033, -0.03 , -0.03 , ...,  0.123,  0.126,  0.129]),
#    'V6': array([-0.057, -0.054, -0.054, ...,  0.093,  0.093,  0.093])},
#   'P57': {'I': array([ 0.225,  0.234,  0.24 , ..., -0.033, -0.03 , -0.024]),
#    'II': array([0.417, 0.447, 0.48 , ..., 0.093, 0.093, 0.093]),
#    'III': array([0.192, 0.213, 0.24 , ..., 0.129, 0.126, 0.12 ]),
#    'AVR': array([ 0.021,  0.015,  0.003, ..., -0.081, -0.075, -0.072]),
#    'AVL': array([-0.318, -0.339, -0.357, ..., -0.03 , -0.03 , -0.033]),
#    'AVF': array([0.303, 0.333, 0.36 , ..., 0.111, 0.108, 0.108]),
#    'V1': array([-0.156, -0.162, -0.165, ...,  0.024,  0.024,  0.021]),
#    'V2': array([0.207, 0.219, 0.237, ..., 0.024, 0.024, 0.021]),
#    'V3': array([0.306, 0.336, 0.366, ..., 0.126, 0.12 , 0.12 ]),
#    'V4': array([0.516, 0.555, 0.597, ..., 0.12 , 0.117, 0.114]),
#    'V5': array([0.54 , 0.579, 0.621, ..., 0.096, 0.093, 0.09 ]),
#    'V6': array([0.507, 0.543, 0.582, ..., 0.066, 0.063, 0.06 ])},
#   'P6': {'I': array([-0.036, -0.039, -0.042, ..., -0.006, -0.006, -0.009]),
#    'II': array([-0.003, -0.006, -0.006, ...,  0.042,  0.045,  0.048]),
#    'III': array([0.03 , 0.033, 0.036, ..., 0.054, 0.054, 0.06 ]),
#    'AVR': array([-0.033, -0.036, -0.039, ..., -0.03 , -0.03 , -0.036]),
#    'AVL': array([ 0.018,  0.021,  0.021, ..., -0.018, -0.018, -0.018]),
#    'AVF': array([0.012, 0.015, 0.015, ..., 0.048, 0.051, 0.054]),
#    'V1': array([ 0.063,  0.063,  0.063, ...,  0.   , -0.003, -0.003]),
#    'V2': array([0.09 , 0.09 , 0.09 , ..., 0.021, 0.021, 0.021]),
#    'V3': array([0.222, 0.225, 0.225, ..., 0.066, 0.066, 0.066]),
#    'V4': array([0.123, 0.123, 0.123, ..., 0.087, 0.087, 0.087]),
#    'V5': array([0.   , 0.   , 0.   , ..., 0.087, 0.087, 0.087]),
#    'V6': array([-0.045, -0.042, -0.042, ...,  0.063,  0.063,  0.063])},
#   'P96': {'I': array([-0.048, -0.051, -0.051, ..., -0.027, -0.024, -0.021]),
#    'II': array([-0.009, -0.009, -0.009, ...,  0.105,  0.105,  0.105]),
#    'III': array([0.036, 0.039, 0.039, ..., 0.138, 0.132, 0.126]),
#    'AVR': array([-0.042, -0.045, -0.045, ..., -0.084, -0.081, -0.075]),
#    'AVL': array([ 0.027,  0.03 ,  0.03 , ..., -0.039, -0.039, -0.039]),
#    'AVF': array([0.012, 0.015, 0.015, ..., 0.12 , 0.117, 0.114]),
#    'V1': array([0.066, 0.069, 0.069, ..., 0.027, 0.024, 0.024]),
#    'V2': array([0.066, 0.069, 0.069, ..., 0.021, 0.018, 0.015]),
#    'V3': array([0.057, 0.057, 0.06 , ..., 0.171, 0.171, 0.168]),
#    'V4': array([-0.015, -0.015, -0.015, ...,  0.159,  0.153,  0.153]),
#    'V5': array([-0.063, -0.063, -0.06 , ...,  0.123,  0.12 ,  0.12 ]),
#    'V6': array([-0.081, -0.081, -0.081, ...,  0.087,  0.084,  0.084])},
#   'P43': {'I': array([0.033, 0.033, 0.033, ..., 0.024, 0.027, 0.027]),
#    'II': array([-0.624, -0.624, -0.621, ..., -0.078, -0.081, -0.081]),
#    'III': array([-0.654, -0.657, -0.654, ..., -0.105, -0.108, -0.108]),
#    'AVR': array([0.345, 0.348, 0.345, ..., 0.063, 0.066, 0.066]),
#    'AVL': array([0.294, 0.294, 0.294, ..., 0.024, 0.024, 0.024]),
#    'AVF': array([-0.639, -0.642, -0.639, ..., -0.093, -0.093, -0.096]),
#    'V1': array([-0.072, -0.072, -0.069, ..., -0.018, -0.018, -0.018]),
#    'V2': array([-0.102, -0.099, -0.096, ...,  0.033,  0.03 ,  0.027]),
#    'V3': array([-0.513, -0.516, -0.516, ..., -0.03 , -0.03 , -0.03 ]),
#    'V4': array([-0.525, -0.528, -0.528, ..., -0.021, -0.024, -0.024]),
#    'V5': array([-0.501, -0.501, -0.501, ..., -0.042, -0.042, -0.042]),
#    'V6': array([-0.42 , -0.42 , -0.42 , ..., -0.048, -0.051, -0.051])},
#   'P46': {'I': array([-0.03 , -0.033, -0.033, ..., -0.012, -0.012, -0.009]),
#    'II': array([-0.036, -0.036, -0.036, ...,  0.081,  0.081,  0.081]),
#    'III': array([-0.006, -0.003,  0.   , ...,  0.096,  0.093,  0.093]),
#    'AVR': array([-0.012, -0.012, -0.015, ..., -0.054, -0.051, -0.051]),
#    'AVL': array([ 0.033,  0.033,  0.036, ..., -0.033, -0.033, -0.033]),
#    'AVF': array([-0.021, -0.021, -0.018, ...,  0.087,  0.087,  0.087]),
#    'V1': array([0.045, 0.048, 0.051, ..., 0.015, 0.015, 0.015]),
#    'V2': array([0.069, 0.069, 0.072, ..., 0.015, 0.015, 0.018]),
#    'V3': array([0.057, 0.06 , 0.063, ..., 0.138, 0.138, 0.138]),
#    'V4': array([0.   , 0.003, 0.003, ..., 0.135, 0.135, 0.138]),
#    'V5': array([-0.048, -0.048, -0.045, ...,  0.114,  0.114,  0.114]),
#    'V6': array([-0.078, -0.075, -0.075, ...,  0.078,  0.078,  0.078])},
#   'P8': {'I': array([-0.126, -0.132, -0.135, ...,  0.033,  0.03 ,  0.027]),
#    'II': array([ 0.069,  0.057,  0.045, ..., -0.003, -0.003, -0.003]),
#    'III': array([ 0.201,  0.195,  0.189, ..., -0.036, -0.033, -0.03 ]),
#    'AVR': array([-0.162, -0.162, -0.159, ...,  0.033,  0.03 ,  0.027]),
#    'AVL': array([ 0.027,  0.036,  0.042, ..., -0.012, -0.012, -0.012]),
#    'AVF': array([ 0.138,  0.129,  0.12 , ..., -0.021, -0.018, -0.015]),
#    'V1': array([ 0.126,  0.12 ,  0.114, ..., -0.033, -0.03 , -0.027]),
#    'V2': array([-0.159, -0.165, -0.168, ...,  0.051,  0.051,  0.054]),
#    'V3': array([0.207, 0.183, 0.159, ..., 0.006, 0.009, 0.009]),
#    'V4': array([0.069, 0.051, 0.036, ..., 0.057, 0.057, 0.057]),
#    'V5': array([-0.003, -0.012, -0.021, ...,  0.057,  0.06 ,  0.06 ]),
#    'V6': array([-0.066, -0.069, -0.075, ...,  0.051,  0.051,  0.054])},
#   'P77': {'I': array([ 0.006,  0.006,  0.012, ..., -0.027, -0.03 , -0.03 ]),
#    'II': array([0.009, 0.006, 0.006, ..., 0.108, 0.108, 0.108]),
#    'III': array([ 0.   ,  0.   , -0.006, ...,  0.138,  0.141,  0.141]),
#    'AVR': array([ 0.   ,  0.003,  0.009, ..., -0.084, -0.084, -0.084]),
#    'AVL': array([-0.006, -0.006, -0.009, ..., -0.042, -0.039, -0.039]),
#    'AVF': array([0.003, 0.003, 0.   , ..., 0.123, 0.126, 0.123]),
#    'V1': array([-0.018, -0.018, -0.021, ...,  0.027,  0.03 ,  0.03 ]),
#    'V2': array([ 0.   , -0.003, -0.006, ...,  0.03 ,  0.03 ,  0.03 ]),
#    'V3': array([0.018, 0.015, 0.012, ..., 0.168, 0.171, 0.171]),
#    'V4': array([0.048, 0.045, 0.042, ..., 0.162, 0.162, 0.162]),
#    'V5': array([0.048, 0.048, 0.048, ..., 0.129, 0.129, 0.129]),
#    'V6': array([0.042, 0.042, 0.042, ..., 0.096, 0.096, 0.096])},
#   'P128': {'I': array([ 0.03 ,  0.03 ,  0.024, ..., -0.003, -0.006, -0.009]),
#    'II': array([0.024, 0.021, 0.021, ..., 0.129, 0.126, 0.123]),
#    'III': array([-0.006, -0.006, -0.003, ...,  0.135,  0.135,  0.135]),
#    'AVR': array([ 0.018,  0.018,  0.015, ..., -0.069, -0.072, -0.072]),
#    'AVL': array([-0.027, -0.024, -0.021, ..., -0.063, -0.06 , -0.057]),
#    'AVF': array([0.009, 0.006, 0.006, ..., 0.132, 0.132, 0.129]),
#    'V1': array([-0.018, -0.018, -0.018, ...,  0.024,  0.024,  0.021]),
#    'V2': array([-0.009, -0.006, -0.006, ...,  0.054,  0.054,  0.054]),
#    'V3': array([0.027, 0.027, 0.03 , ..., 0.177, 0.174, 0.171]),
#    'V4': array([0.042, 0.045, 0.048, ..., 0.186, 0.186, 0.186]),
#    'V5': array([0.042, 0.045, 0.048, ..., 0.144, 0.144, 0.144]),
#    'V6': array([0.027, 0.03 , 0.033, ..., 0.105, 0.105, 0.105])},
#   'P137': {'I': array([-0.003,  0.012,  0.036, ...,  0.006,  0.003,  0.006]),
#    'II': array([ 0.03 ,  0.039,  0.042, ..., -0.096, -0.096, -0.093]),
#    'III': array([ 0.039,  0.03 ,  0.006, ..., -0.102, -0.102, -0.099]),
#    'AVR': array([-0.021, -0.006,  0.015, ...,  0.054,  0.051,  0.051]),
#    'AVL': array([-0.015, -0.027, -0.039, ...,  0.042,  0.042,  0.042]),
#    'AVF': array([ 0.033,  0.03 ,  0.021, ..., -0.099, -0.096, -0.096]),
#    'V1': array([ 0.003, -0.012, -0.033, ..., -0.015, -0.018, -0.018]),
#    'V2': array([ 0.198,  0.225,  0.252, ..., -0.018, -0.018, -0.021]),
#    'V3': array([0.123, 0.129, 0.132, ..., 0.024, 0.021, 0.018]),
#    'V4': array([0.171, 0.198, 0.222, ..., 0.057, 0.054, 0.051]),
#    'V5': array([0.147, 0.174, 0.201, ..., 0.072, 0.069, 0.069]),
#    'V6': array([0.114, 0.141, 0.168, ..., 0.051, 0.051, 0.051])},
#   'P118': {'I': array([ 0.021,  0.024,  0.027, ..., -0.012, -0.012, -0.015]),
#    'II': array([0.021, 0.021, 0.021, ..., 0.147, 0.147, 0.147]),
#    'III': array([ 0.   ,  0.   , -0.003, ...,  0.159,  0.162,  0.165]),
#    'AVR': array([ 0.009,  0.012,  0.015, ..., -0.084, -0.087, -0.093]),
#    'AVL': array([-0.021, -0.024, -0.024, ..., -0.066, -0.066, -0.063]),
#    'AVF': array([0.012, 0.009, 0.009, ..., 0.153, 0.153, 0.156]),
#    'V1': array([-0.021, -0.024, -0.027, ...,  0.024,  0.024,  0.027]),
#    'V2': array([-0.003, -0.006, -0.006, ...,  0.051,  0.051,  0.051]),
#    'V3': array([0.015, 0.012, 0.009, ..., 0.189, 0.189, 0.189]),
#    'V4': array([0.039, 0.036, 0.033, ..., 0.18 , 0.18 , 0.18 ]),
#    'V5': array([0.048, 0.045, 0.045, ..., 0.153, 0.153, 0.153]),
#    'V6': array([0.036, 0.033, 0.033, ..., 0.105, 0.108, 0.105])},
#   'P21': {'I': array([-0.123, -0.12 , -0.117, ..., -0.039, -0.048, -0.054]),
#    'II': array([-0.195, -0.195, -0.195, ...,  0.012,  0.009,  0.009]),
#    'III': array([-0.066, -0.069, -0.075, ...,  0.057,  0.06 ,  0.063]),
#    'AVR': array([-0.027, -0.024, -0.018, ..., -0.048, -0.054, -0.06 ]),
#    'AVL': array([0.156, 0.156, 0.156, ..., 0.012, 0.015, 0.021]),
#    'AVF': array([-0.132, -0.132, -0.135, ...,  0.033,  0.036,  0.036]),
#    'V1': array([0.297, 0.273, 0.246, ..., 0.036, 0.036, 0.036]),
#    'V2': array([-0.042, -0.06 , -0.078, ..., -0.063, -0.063, -0.06 ]),
#    'V3': array([-0.027, -0.042, -0.054, ...,  0.015,  0.015,  0.015]),
#    'V4': array([-0.198, -0.198, -0.198, ..., -0.027, -0.027, -0.03 ]),
#    'V5': array([-0.249, -0.243, -0.237, ..., -0.03 , -0.03 , -0.03 ]),
#    'V6': array([-0.258, -0.249, -0.243, ..., -0.03 , -0.03 , -0.03 ])},
#   'P93': {'I': array([ 0.006,  0.009,  0.015, ..., -0.033, -0.03 , -0.024]),
#    'II': array([0.   , 0.   , 0.   , ..., 0.111, 0.111, 0.108]),
#    'III': array([-0.003, -0.009, -0.015, ...,  0.147,  0.141,  0.135]),
#    'AVR': array([ 0.006,  0.009,  0.015, ..., -0.09 , -0.084, -0.078]),
#    'AVL': array([-0.003, -0.006, -0.006, ..., -0.039, -0.039, -0.042]),
#    'AVF': array([ 0.   , -0.003, -0.006, ...,  0.129,  0.126,  0.12 ]),
#    'V1': array([-0.018, -0.018, -0.018, ...,  0.024,  0.024,  0.021]),
#    'V2': array([-0.006, -0.009, -0.012, ...,  0.03 ,  0.024,  0.021]),
#    'V3': array([0.024, 0.021, 0.018, ..., 0.174, 0.171, 0.165]),
#    'V4': array([0.036, 0.033, 0.03 , ..., 0.159, 0.156, 0.153]),
#    'V5': array([0.036, 0.033, 0.03 , ..., 0.129, 0.126, 0.123]),
#    'V6': array([0.033, 0.03 , 0.027, ..., 0.093, 0.09 , 0.087])},
#   'P24': {'I': array([ 0.006,  0.009,  0.012, ..., -0.024, -0.018, -0.012]),
#    'II': array([-0.003, -0.006, -0.006, ...,  0.075,  0.075,  0.075]),
#    'III': array([-0.012, -0.015, -0.021, ...,  0.099,  0.093,  0.09 ]),
#    'AVR': array([ 0.009,  0.012,  0.015, ..., -0.06 , -0.057, -0.051]),
#    'AVL': array([ 0.   ,  0.   ,  0.   , ..., -0.024, -0.03 , -0.033]),
#    'AVF': array([-0.009, -0.012, -0.015, ...,  0.087,  0.084,  0.081]),
#    'V1': array([-0.024, -0.027, -0.027, ...,  0.012,  0.012,  0.009]),
#    'V2': array([-0.015, -0.018, -0.021, ...,  0.03 ,  0.027,  0.027]),
#    'V3': array([-0.015, -0.018, -0.021, ...,  0.114,  0.111,  0.108]),
#    'V4': array([0.003, 0.   , 0.   , ..., 0.111, 0.108, 0.105]),
#    'V5': array([0.018, 0.015, 0.012, ..., 0.087, 0.084, 0.081]),
#    'V6': array([0.015, 0.012, 0.009, ..., 0.06 , 0.057, 0.057])},
#   'P127': {'I': array([ 0.006,  0.009,  0.015, ..., -0.027, -0.027, -0.024]),
#    'II': array([0.018, 0.018, 0.018, ..., 0.108, 0.108, 0.108]),
#    'III': array([0.012, 0.009, 0.006, ..., 0.138, 0.135, 0.135]),
#    'AVR': array([ 0.   ,  0.   ,  0.003, ..., -0.081, -0.081, -0.081]),
#    'AVL': array([-0.012, -0.015, -0.018, ..., -0.042, -0.042, -0.042]),
#    'AVF': array([0.015, 0.015, 0.015, ..., 0.123, 0.12 , 0.12 ]),
#    'V1': array([-0.015, -0.012, -0.012, ...,  0.021,  0.021,  0.021]),
#    'V2': array([0.015, 0.018, 0.018, ..., 0.063, 0.063, 0.063]),
#    'V3': array([0.018, 0.021, 0.018, ..., 0.171, 0.171, 0.171]),
#    'V4': array([0.057, 0.06 , 0.06 , ..., 0.174, 0.174, 0.174]),
#    'V5': array([0.066, 0.069, 0.069, ..., 0.144, 0.144, 0.144]),
#    'V6': array([0.063, 0.063, 0.063, ..., 0.099, 0.099, 0.099])},
#   'P47': {'I': array([0.003, 0.006, 0.006, ..., 0.021, 0.027, 0.03 ]),
#    'II': array([-0.018, -0.018, -0.015, ...,  0.006,  0.003,  0.003]),
#    'III': array([-0.021, -0.021, -0.021, ..., -0.012, -0.021, -0.024]),
#    'AVR': array([0.012, 0.015, 0.015, ..., 0.018, 0.021, 0.027]),
#    'AVL': array([ 0.006,  0.003,  0.003, ..., -0.015, -0.015, -0.018]),
#    'AVF': array([-0.018, -0.018, -0.018, ..., -0.003, -0.006, -0.009]),
# ...
#    'V5': array([-0.093, -0.093, -0.09 , ...,  0.048,  0.045,  0.045]),
#    'V6': array([-0.126, -0.126, -0.123, ...,  0.042,  0.039,  0.036])},
#   'P12': {'I': array([-0.042, -0.045, -0.045, ..., -0.087, -0.09 , -0.093]),
#    'II': array([-0.027, -0.024, -0.024, ..., -0.453, -0.456, -0.456]),
#    'III': array([ 0.012,  0.018,  0.021, ..., -0.366, -0.366, -0.363]),
#    'AVR': array([-0.027, -0.03 , -0.033, ...,  0.138,  0.135,  0.132]),
#    'AVL': array([0.033, 0.036, 0.036, ..., 0.267, 0.27 , 0.27 ]),
#    'AVF': array([-0.006, -0.003,  0.   , ..., -0.411, -0.411, -0.411]),
#    'V1': array([0.045, 0.048, 0.051, ..., 0.069, 0.072, 0.072]),
#    'V2': array([ 0.051,  0.054,  0.057, ..., -0.03 , -0.03 , -0.03 ]),
#    'V3': array([ 0.042,  0.042,  0.048, ..., -0.285, -0.282, -0.282]),
#    'V4': array([ 0.   ,  0.   ,  0.   , ..., -0.399, -0.396, -0.396]),
#    'V5': array([-0.03 , -0.03 , -0.03 , ..., -0.45 , -0.45 , -0.447]),
#    'V6': array([-0.054, -0.051, -0.051, ..., -0.441, -0.441, -0.441])},
#   'P1': {'I': array([-0.012, -0.012, -0.015, ...,  0.   , -0.009, -0.015]),
#    'II': array([-0.063, -0.066, -0.066, ...,  0.087,  0.087,  0.087]),
#    'III': array([-0.051, -0.054, -0.054, ...,  0.09 ,  0.099,  0.102]),
#    'AVR': array([ 0.018,  0.018,  0.018, ..., -0.045, -0.051, -0.057]),
#    'AVL': array([ 0.036,  0.039,  0.042, ..., -0.042, -0.039, -0.036]),
#    'AVF': array([-0.057, -0.06 , -0.06 , ...,  0.087,  0.093,  0.093]),
#    'V1': array([0.012, 0.015, 0.018, ..., 0.057, 0.057, 0.057]),
#    'V2': array([0.084, 0.087, 0.087, ..., 0.   , 0.   , 0.003]),
#    'V3': array([0.012, 0.015, 0.018, ..., 0.15 , 0.15 , 0.153]),
#    'V4': array([-0.015, -0.012, -0.012, ...,  0.093,  0.096,  0.096]),
#    'V5': array([-0.045, -0.045, -0.045, ...,  0.081,  0.084,  0.087]),
#    'V6': array([-0.036, -0.033, -0.033, ...,  0.057,  0.057,  0.06 ])},
#   'P40': {'I': array([-0.063, -0.06 , -0.057, ..., -0.036, -0.033, -0.027]),
#    'II': array([-0.015, -0.015, -0.015, ...,  0.066,  0.063,  0.063]),
#    'III': array([0.051, 0.045, 0.042, ..., 0.102, 0.099, 0.093]),
#    'AVR': array([-0.057, -0.051, -0.048, ..., -0.069, -0.066, -0.06 ]),
#    'AVL': array([ 0.039,  0.036,  0.036, ..., -0.015, -0.015, -0.018]),
#    'AVF': array([0.018, 0.012, 0.012, ..., 0.084, 0.081, 0.078]),
#    'V1': array([0.078, 0.075, 0.075, ..., 0.018, 0.018, 0.015]),
#    'V2': array([0.09 , 0.087, 0.084, ..., 0.003, 0.003, 0.003]),
#    'V3': array([0.153, 0.153, 0.153, ..., 0.084, 0.087, 0.084]),
#    'V4': array([0.075, 0.072, 0.069, ..., 0.09 , 0.09 , 0.087]),
#    'V5': array([-0.012, -0.012, -0.015, ...,  0.084,  0.081,  0.078]),
#    'V6': array([-0.057, -0.06 , -0.063, ...,  0.069,  0.069,  0.066])},
#   'P4': {'I': array([-0.054, -0.054, -0.054, ...,  0.009,  0.006,  0.006]),
#    'II': array([-0.03 , -0.033, -0.036, ...,  0.012,  0.012,  0.009]),
#    'III': array([0.021, 0.021, 0.015, ..., 0.003, 0.003, 0.003]),
#    'AVR': array([-0.036, -0.039, -0.036, ...,  0.003,  0.   ,  0.   ]),
#    'AVL': array([ 0.039,  0.045,  0.045, ..., -0.012, -0.009, -0.006]),
#    'AVF': array([-0.003, -0.006, -0.009, ...,  0.009,  0.006,  0.006]),
#    'V1': array([ 0.042,  0.042,  0.039, ..., -0.012, -0.012, -0.012]),
#    'V2': array([0.048, 0.048, 0.045, ..., 0.   , 0.   , 0.   ]),
#    'V3': array([0.048, 0.048, 0.045, ..., 0.018, 0.021, 0.018]),
#    'V4': array([-0.012, -0.012, -0.015, ...,  0.045,  0.045,  0.042]),
#    'V5': array([-0.054, -0.057, -0.06 , ...,  0.045,  0.045,  0.045]),
#    'V6': array([-0.084, -0.087, -0.09 , ...,  0.042,  0.042,  0.042])},
#   'P34': {'I': array([ 0.03 ,  0.027,  0.021, ..., -0.009, -0.009, -0.012]),
#    'II': array([0.018, 0.018, 0.018, ..., 0.105, 0.105, 0.105]),
#    'III': array([-0.009, -0.006,  0.   , ...,  0.12 ,  0.117,  0.12 ]),
#    'AVR': array([ 0.018,  0.015,  0.012, ..., -0.066, -0.063, -0.066]),
#    'AVL': array([-0.021, -0.021, -0.018, ..., -0.048, -0.048, -0.045]),
#    'AVF': array([0.003, 0.003, 0.006, ..., 0.114, 0.111, 0.111]),
#    'V1': array([-0.042, -0.042, -0.042, ...,  0.027,  0.027,  0.027]),
#    'V2': array([0.   , 0.   , 0.   , ..., 0.021, 0.018, 0.018]),
#    'V3': array([0.012, 0.012, 0.015, ..., 0.165, 0.165, 0.165]),
#    'V4': array([0.042, 0.042, 0.045, ..., 0.156, 0.153, 0.153]),
#    'V5': array([0.054, 0.054, 0.054, ..., 0.126, 0.126, 0.126]),
#    'V6': array([0.042, 0.042, 0.045, ..., 0.078, 0.078, 0.075])},
#   'P36': {'I': array([ 0.   ,  0.003,  0.012, ..., -0.036, -0.036, -0.033]),
#    'II': array([0.048, 0.048, 0.045, ..., 0.105, 0.102, 0.102]),
#    'III': array([0.048, 0.042, 0.033, ..., 0.144, 0.141, 0.138]),
#    'AVR': array([-0.024, -0.018, -0.009, ..., -0.09 , -0.087, -0.084]),
#    'AVL': array([-0.024, -0.027, -0.03 , ..., -0.033, -0.033, -0.033]),
#    'AVF': array([0.048, 0.045, 0.039, ..., 0.123, 0.123, 0.12 ]),
#    'V1': array([-0.009, -0.015, -0.018, ...,  0.018,  0.018,  0.015]),
#    'V2': array([0.009, 0.006, 0.006, ..., 0.015, 0.012, 0.009]),
#    'V3': array([0.006, 0.006, 0.003, ..., 0.156, 0.153, 0.15 ]),
#    'V4': array([-0.012, -0.012, -0.012, ...,  0.141,  0.138,  0.135]),
#    'V5': array([-0.024, -0.021, -0.021, ...,  0.111,  0.108,  0.102]),
#    'V6': array([-0.027, -0.024, -0.024, ...,  0.081,  0.075,  0.075])},
#   'P35': {'I': array([ 0.003,  0.009,  0.015, ..., -0.027, -0.024, -0.021]),
#    'II': array([0.027, 0.027, 0.03 , ..., 0.108, 0.108, 0.108]),
#    'III': array([0.024, 0.018, 0.012, ..., 0.141, 0.135, 0.129]),
#    'AVR': array([-0.009, -0.006,  0.   , ..., -0.084, -0.081, -0.075]),
#    'AVL': array([-0.015, -0.018, -0.021, ..., -0.039, -0.042, -0.042]),
#    'AVF': array([0.024, 0.021, 0.021, ..., 0.126, 0.123, 0.12 ]),
#    'V1': array([-0.033, -0.036, -0.036, ...,  0.03 ,  0.027,  0.024]),
#    'V2': array([-0.009, -0.012, -0.012, ...,  0.045,  0.042,  0.039]),
#    'V3': array([0.024, 0.024, 0.021, ..., 0.186, 0.186, 0.183]),
#    'V4': array([0.042, 0.039, 0.039, ..., 0.18 , 0.177, 0.174]),
#    'V5': array([0.057, 0.054, 0.054, ..., 0.153, 0.15 , 0.147]),
#    'V6': array([0.045, 0.042, 0.042, ..., 0.114, 0.111, 0.108])},
#   'P18': {'I': array([-0.024, -0.021, -0.015, ...,  0.009,  0.012,  0.015]),
#    'II': array([-0.027, -0.024, -0.021, ...,  0.012,  0.012,  0.009]),
#    'III': array([-0.006, -0.006, -0.003, ...,  0.003,  0.   , -0.006]),
#    'AVR': array([-0.012, -0.012, -0.009, ...,  0.   ,  0.006,  0.012]),
#    'AVL': array([ 0.021,  0.018,  0.015, ..., -0.012, -0.012, -0.012]),
#    'AVF': array([-0.015, -0.012, -0.012, ...,  0.009,  0.006,  0.   ]),
#    'V1': array([ 0.015,  0.012,  0.009, ..., -0.018, -0.021, -0.024]),
#    'V2': array([-0.024, -0.024, -0.021, ..., -0.003, -0.009, -0.012]),
#    'V3': array([-0.033, -0.03 , -0.027, ...,  0.018,  0.015,  0.009]),
#    'V4': array([-0.027, -0.027, -0.024, ...,  0.042,  0.036,  0.033]),
#    'V5': array([-0.021, -0.024, -0.024, ...,  0.048,  0.042,  0.039]),
#    'V6': array([-0.021, -0.024, -0.024, ...,  0.042,  0.036,  0.036])},
#   'P16': {'I': array([-0.036, -0.036, -0.039, ..., -0.018, -0.018, -0.015]),
#    'II': array([-0.021, -0.021, -0.018, ...,  0.099,  0.105,  0.108]),
#    'III': array([0.015, 0.015, 0.018, ..., 0.12 , 0.123, 0.126]),
#    'AVR': array([-0.027, -0.027, -0.03 , ..., -0.069, -0.072, -0.069]),
#    'AVL': array([ 0.027,  0.027,  0.03 , ..., -0.042, -0.045, -0.048]),
#    'AVF': array([0.   , 0.   , 0.   , ..., 0.111, 0.114, 0.117]),
#    'V1': array([0.048, 0.048, 0.051, ..., 0.012, 0.015, 0.018]),
#    'V2': array([0.057, 0.054, 0.051, ..., 0.033, 0.033, 0.03 ]),
#    'V3': array([0.054, 0.051, 0.054, ..., 0.153, 0.159, 0.162]),
#    'V4': array([0.  , 0.  , 0.  , ..., 0.15, 0.15, 0.15]),
#    'V5': array([-0.036, -0.036, -0.039, ...,  0.12 ,  0.123,  0.123]),
#    'V6': array([-0.063, -0.063, -0.066, ...,  0.087,  0.09 ,  0.09 ])},
#   'P14': {'I': array([ 0.042,  0.042,  0.045, ..., -0.015, -0.021, -0.027]),
#    'II': array([0.063, 0.072, 0.075, ..., 0.075, 0.072, 0.069]),
#    'III': array([0.024, 0.027, 0.027, ..., 0.093, 0.096, 0.102]),
#    'AVR': array([ 0.006,  0.003,  0.   , ..., -0.054, -0.06 , -0.063]),
#    'AVL': array([-0.051, -0.057, -0.057, ..., -0.027, -0.024, -0.021]),
#    'AVF': array([0.045, 0.048, 0.051, ..., 0.084, 0.084, 0.084]),
#    'V1': array([-0.036, -0.036, -0.039, ...,  0.021,  0.021,  0.021]),
#    'V2': array([0.012, 0.018, 0.021, ..., 0.015, 0.015, 0.018]),
#    'V3': array([0.03 , 0.036, 0.039, ..., 0.117, 0.114, 0.114]),
#    'V4': array([0.072, 0.078, 0.081, ..., 0.093, 0.093, 0.093]),
#    'V5': array([0.081, 0.087, 0.09 , ..., 0.069, 0.069, 0.069]),
#    'V6': array([0.081, 0.087, 0.093, ..., 0.048, 0.048, 0.048])},
#   'P31': {'I': array([ 0.027,  0.027,  0.027, ..., -0.015, -0.012, -0.009]),
#    'II': array([0.03 , 0.03 , 0.03 , ..., 0.105, 0.105, 0.105]),
#    'III': array([0.003, 0.   , 0.   , ..., 0.123, 0.12 , 0.117]),
#    'AVR': array([ 0.009,  0.012,  0.012, ..., -0.069, -0.066, -0.066]),
#    'AVL': array([-0.03 , -0.03 , -0.03 , ..., -0.045, -0.045, -0.048]),
#    'AVF': array([0.018, 0.015, 0.015, ..., 0.114, 0.111, 0.111]),
#    'V1': array([-0.03 , -0.03 , -0.03 , ...,  0.024,  0.021,  0.021]),
#    'V2': array([0.   , 0.   , 0.   , ..., 0.036, 0.033, 0.03 ]),
#    'V3': array([0.03 , 0.03 , 0.033, ..., 0.159, 0.159, 0.159]),
#    'V4': array([0.063, 0.063, 0.063, ..., 0.141, 0.138, 0.138]),
#    'V5': array([0.063, 0.063, 0.066, ..., 0.105, 0.105, 0.102]),
#    'V6': array([0.051, 0.051, 0.054, ..., 0.102, 0.102, 0.099])},
#   'P8': {'I': array([-0.024, -0.018, -0.009, ..., -0.015, -0.015, -0.021]),
#    'II': array([-0.024, -0.024, -0.024, ...,  0.126,  0.123,  0.12 ]),
#    'III': array([ 0.   , -0.006, -0.015, ...,  0.141,  0.138,  0.141]),
#    'AVR': array([-0.012, -0.003,  0.003, ..., -0.078, -0.078, -0.081]),
#    'AVL': array([ 0.024,  0.021,  0.015, ..., -0.054, -0.054, -0.048]),
#    'AVF': array([-0.012, -0.018, -0.021, ...,  0.132,  0.129,  0.129]),
#    'V1': array([0.033, 0.03 , 0.03 , ..., 0.024, 0.024, 0.024]),
#    'V2': array([0.066, 0.066, 0.063, ..., 0.024, 0.024, 0.024]),
#    'V3': array([0.021, 0.018, 0.018, ..., 0.165, 0.162, 0.159]),
#    'V4': array([-0.015, -0.021, -0.024, ...,  0.159,  0.156,  0.153]),
#    'V5': array([-0.072, -0.075, -0.078, ...,  0.126,  0.123,  0.12 ]),
#    'V6': array([-0.069, -0.072, -0.075, ...,  0.084,  0.081,  0.081])},
#   'P30': {'I': array([ 0.024,  0.03 ,  0.033, ..., -0.021, -0.021, -0.024]),
#    'II': array([0.018, 0.018, 0.018, ..., 0.114, 0.114, 0.114]),
#    'III': array([-0.006, -0.009, -0.009, ...,  0.138,  0.141,  0.141]),
#    'AVR': array([ 0.015,  0.018,  0.021, ..., -0.078, -0.081, -0.081]),
#    'AVL': array([-0.021, -0.024, -0.027, ..., -0.045, -0.045, -0.045]),
#    'AVF': array([0.006, 0.003, 0.003, ..., 0.126, 0.126, 0.126]),
#    'V1': array([-0.027, -0.027, -0.027, ...,  0.024,  0.027,  0.027]),
#    'V2': array([0.015, 0.012, 0.012, ..., 0.018, 0.018, 0.021]),
#    'V3': array([0.021, 0.021, 0.021, ..., 0.159, 0.159, 0.162]),
#    'V4': array([0.051, 0.051, 0.051, ..., 0.141, 0.144, 0.147]),
#    'V5': array([0.066, 0.063, 0.06 , ..., 0.114, 0.114, 0.117]),
#    'V6': array([0.057, 0.057, 0.057, ..., 0.072, 0.072, 0.072])},
#   'P6': {'I': array([-0.024, -0.027, -0.036, ..., -0.012, -0.015, -0.021]),
#    'II': array([-0.03 , -0.03 , -0.027, ...,  0.126,  0.126,  0.126]),
#    'III': array([-0.006,  0.   ,  0.006, ...,  0.141,  0.144,  0.147]),
#    'AVR': array([-0.006, -0.012, -0.021, ..., -0.075, -0.081, -0.084]),
#    'AVL': array([ 0.027,  0.03 ,  0.033, ..., -0.057, -0.054, -0.051]),
#    'AVF': array([-0.018, -0.015, -0.009, ...,  0.132,  0.135,  0.135]),
#    'V1': array([0.048, 0.051, 0.051, ..., 0.018, 0.018, 0.018]),
#    'V2': array([0.027, 0.033, 0.033, ..., 0.021, 0.021, 0.021]),
#    'V3': array([0.018, 0.018, 0.018, ..., 0.162, 0.162, 0.162]),
#    'V4': array([-0.06 , -0.06 , -0.06 , ...,  0.15 ,  0.153,  0.153]),
#    'V5': array([-0.114, -0.114, -0.114, ...,  0.123,  0.126,  0.126]),
#    'V6': array([-0.12 , -0.117, -0.117, ...,  0.09 ,  0.09 ,  0.093])},
#   'P17': {'I': array([-0.039, -0.033, -0.03 , ..., -0.096, -0.09 , -0.087]),
#    'II': array([-0.063, -0.06 , -0.054, ..., -0.516, -0.516, -0.516]),
#    'III': array([-0.021, -0.021, -0.021, ..., -0.42 , -0.426, -0.429]),
#    'AVR': array([-0.009, -0.006, -0.003, ...,  0.162,  0.168,  0.171]),
#    'AVL': array([0.051, 0.048, 0.042, ..., 0.306, 0.303, 0.3  ]),
#    'AVF': array([-0.042, -0.042, -0.039, ..., -0.468, -0.471, -0.471]),
#    'V1': array([0.054, 0.051, 0.051, ..., 0.078, 0.072, 0.072]),
#    'V2': array([ 0.087,  0.087,  0.087, ..., -0.018, -0.021, -0.024]),
#    'V3': array([ 0.045,  0.045,  0.045, ..., -0.288, -0.291, -0.291]),
#    'V4': array([ 0.   ,  0.003,  0.003, ..., -0.402, -0.405, -0.405]),
#    'V5': array([-0.06 , -0.06 , -0.057, ..., -0.453, -0.459, -0.459]),
#    'V6': array([-0.081, -0.078, -0.075, ..., -0.447, -0.45 , -0.45 ])},
#   'P11': {'I': array([-0.048, -0.045, -0.042, ..., -0.024, -0.024, -0.021]),
#    'II': array([-0.045, -0.045, -0.042, ...,  0.108,  0.108,  0.105]),
#    'III': array([0.003, 0.   , 0.   , ..., 0.138, 0.135, 0.129]),
#    'AVR': array([-0.027, -0.024, -0.021, ..., -0.081, -0.081, -0.075]),
#    'AVL': array([ 0.045,  0.045,  0.042, ..., -0.042, -0.042, -0.042]),
#    'AVF': array([-0.018, -0.021, -0.021, ...,  0.123,  0.12 ,  0.117]),
#    'V1': array([0.054, 0.051, 0.051, ..., 0.021, 0.018, 0.018]),
#    'V2': array([0.075, 0.075, 0.072, ..., 0.03 , 0.027, 0.024]),
#    'V3': array([0.066, 0.063, 0.063, ..., 0.168, 0.165, 0.162]),
#    'V4': array([0.006, 0.003, 0.003, ..., 0.159, 0.159, 0.156]),
#    'V5': array([-0.03 , -0.033, -0.033, ...,  0.135,  0.132,  0.129]),
#    'V6': array([-0.063, -0.066, -0.066, ...,  0.102,  0.099,  0.093])},
#   'P26': {'I': array([ 0.024,  0.024,  0.021, ..., -0.018, -0.021, -0.024]),
#    'II': array([0.042, 0.042, 0.042, ..., 0.111, 0.108, 0.108]),
#    'III': array([0.018, 0.018, 0.018, ..., 0.132, 0.135, 0.135]),
#    'AVR': array([ 0.   ,  0.   ,  0.   , ..., -0.075, -0.078, -0.078]),
#    'AVL': array([-0.03 , -0.033, -0.033, ..., -0.045, -0.042, -0.042]),
#    'AVF': array([0.03 , 0.03 , 0.03 , ..., 0.12 , 0.12 , 0.123]),
#    'V1': array([-0.024, -0.018, -0.012, ...,  0.024,  0.027,  0.027]),
#    'V2': array([0.012, 0.015, 0.018, ..., 0.039, 0.039, 0.039]),
#    'V3': array([0.039, 0.039, 0.039, ..., 0.156, 0.156, 0.159]),
#    'V4': array([0.072, 0.072, 0.075, ..., 0.15 , 0.15 , 0.15 ]),
#    'V5': array([0.081, 0.084, 0.084, ..., 0.12 , 0.123, 0.123]),
#    'V6': array([0.069, 0.072, 0.072, ..., 0.087, 0.087, 0.087])},
#   'P23': {'I': array([-0.039, -0.036, -0.03 , ..., -0.021, -0.018, -0.018]),
#    'II': array([-0.003,  0.   ,  0.   , ...,  0.105,  0.105,  0.105]),
#    'III': array([0.036, 0.03 , 0.027, ..., 0.129, 0.126, 0.123]),
#    'AVR': array([-0.039, -0.033, -0.03 , ..., -0.075, -0.072, -0.069]),
#    'AVL': array([ 0.021,  0.018,  0.015, ..., -0.042, -0.042, -0.045]),
#    'AVF': array([0.015, 0.012, 0.012, ..., 0.117, 0.114, 0.114]),
#    'V1': array([0.039, 0.039, 0.036, ..., 0.033, 0.033, 0.036]),
#    'V2': array([0.015, 0.012, 0.012, ..., 0.039, 0.036, 0.036]),
#    'V3': array([0.03 , 0.027, 0.027, ..., 0.141, 0.141, 0.141]),
#    'V4': array([-0.069, -0.069, -0.069, ...,  0.135,  0.135,  0.135]),
#    'V5': array([-0.129, -0.126, -0.126, ...,  0.108,  0.108,  0.108]),
#    'V6': array([-0.117, -0.117, -0.117, ...,  0.072,  0.072,  0.069])},
#   'P41': {'I': array([ 0.018,  0.018,  0.018, ..., -0.024, -0.021, -0.018]),
#    'II': array([0.039, 0.036, 0.03 , ..., 0.063, 0.063, 0.063]),
#    'III': array([0.021, 0.015, 0.009, ..., 0.09 , 0.084, 0.081]),
#    'AVR': array([ 0.   ,  0.   ,  0.003, ..., -0.057, -0.054, -0.051]),
#    'AVL': array([-0.03 , -0.027, -0.024, ..., -0.018, -0.021, -0.024]),
#    'AVF': array([0.03 , 0.024, 0.018, ..., 0.075, 0.072, 0.072]),
#    'V1': array([-0.03 , -0.03 , -0.033, ...,  0.015,  0.015,  0.015]),
#    'V2': array([ 0.003,  0.   ,  0.   , ..., -0.027, -0.027, -0.027]),
#    'V3': array([-0.012, -0.015, -0.021, ...,  0.075,  0.072,  0.072]),
#    'V4': array([ 0.   , -0.003, -0.006, ...,  0.066,  0.066,  0.066]),
#    'V5': array([0.018, 0.018, 0.015, ..., 0.063, 0.063, 0.063]),
#    'V6': array([0.018, 0.018, 0.015, ..., 0.039, 0.039, 0.039])}}}

# %% [markdown]
# Hence, the Structures field is a dictionary where:
# - Outer dictionary keys represent anatomical regions (e.g., '2-LV', '1-AO')
# - Each anatomical region has multiple points where the catheter was placed (e.g., 'P36', 'P122')
# - Each of these points holds a standard 12-lead ECG dictonary with keys (e.g., 'I', 'II', etc.)

# %%
# Step: Flatten all_points into signal-level records
signal_records = []

for patient_id, patient_data in all_points.items():
    structures = patient_data.get("Structures", {})
    if not isinstance(structures, dict):  # Prevent error from None
        continue
    
    soo_label = patient_data.get("SOO", [None])[0]  # For Hoja1/Hoja2 mapping

    for structure, signals in structures.items():
        for sample_id, leads in signals.items():
            # Check if all 12 leads are present
            expected_leads = {'I', 'II', 'III', 'AVR', 'AVL', 'AVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6'}
            if set(leads.keys()) >= expected_leads:
                signal_records.append({
                    "PatientID": patient_id,
                    "SampleID": sample_id,
                    "Structure": structure,
                    "Leads": leads,
                    "SOO": soo_label,
                    "Sex": patient_data.get("Sex", [None])[0],
                    "Age": patient_data.get("Age", [None])[0],
                    "PVC_transition": patient_data.get("PVC_transition", [None])[0],
                    "SOO_chamber": patient_data.get("SOO_chamber", [None])[0],
                    "Height": patient_data.get("Height", [None])[0],
                    "Weight": patient_data.get("Weight", [None])[0],
                    "BMI": patient_data.get("BMI", [None])[0],
                    "DM": patient_data.get("DM", [None])[0],
                    "DLP": patient_data.get("DLP", [None])[0],
                    "Smoker": patient_data.get("Smoker", [None])[0],
                    "COPD": patient_data.get("COPD", [None])[0],
                    "Sleep_apnea": patient_data.get("Sleep_apnea", [None])[0],
                    "CLINICAL_SCORE": patient_data.get("CLINICAL_SCORE", [None])[0],
                    "OTorigin": patient_data.get("OTorigin", [None])[0]
                })

# Convert to DataFrame
df_signals = pd.DataFrame(signal_records)
print("Extracted ECG samples:", df_signals.shape)
df_signals.head()
# Out:
# Extracted ECG samples: (29153, 19)
#   PatientID SampleID Structure  \
# 0      P186      P36      2-LV
# 1      P186     P122      2-LV
# 2      P186      P85      2-LV
# 3      P186     P103      2-LV
# 4      P186      P86      2-LV
#
#                                                Leads                 SOO  \
# 0  {'I': [-0.075, -0.075, -0.07200000000000001, -...  Unión mitroaórtica
# 1  {'I': [-0.042, -0.045, -0.048, -0.048, -0.048,...  Unión mitroaórtica
# 2  {'I': [-0.048, -0.045, -0.042, -0.042, -0.042,...  Unión mitroaórtica
# 3  {'I': [-0.045, -0.048, -0.048, -0.048, -0.045,...  Unión mitroaórtica
# 4  {'I': [0.003, 0.009000000000000001, 0.015, 0.0...  Unión mitroaórtica
#
#       Sex   Age PVC_transition      SOO_chamber  Height  Weight  BMI   DM  \
# 0  Female  61.0             V1  Right ventricle     NaN     NaN  NaN  NaN
# 1  Female  61.0             V1  Right ventricle     NaN     NaN  NaN  NaN
# 2  Female  61.0             V1  Right ventricle     NaN     NaN  NaN  NaN
# 3  Female  61.0             V1  Right ventricle     NaN     NaN  NaN  NaN
# 4  Female  61.0             V1  Right ventricle     NaN     NaN  NaN  NaN
#
#    DLP Smoker COPD Sleep_apnea  CLINICAL_SCORE  OTorigin
# 0  NaN    NaN  NaN         NaN             NaN       0.0
# 1  NaN    NaN  NaN         NaN             NaN       0.0
# 2  NaN    NaN  NaN         NaN             NaN       0.0
# 3  NaN    NaN  NaN         NaN             NaN       0.0
# 4  NaN    NaN  NaN         NaN             NaN       0.0

# %% [markdown]
# Even though there is a column SOO_chamber in our dataset, we decided to recompute it based on the mappings from the Excel file labels_FontiersUnsupervised.

# %%
# Load mapping Excel file
labels_path = "data/labels_FontiersUnsupervised.xlsx"
map_hoja1 = pd.read_excel(labels_path, sheet_name="Hoja1")
map_hoja2 = pd.read_excel(labels_path, sheet_name="Hoja2")

# Build mapping dictionaries from Hoja1 and Hoja2
# Task 1: SOO -> SOO_Chamber
map_chamber_1 = dict(zip(map_hoja1["SOO"], map_hoja1["SOO_Chamber"]))
map_chamber_2 = dict(zip(map_hoja2["SOO"], map_hoja2["SOO_chamber"]))

# Task 2: SOO -> Region_Simplified or Simplified
map_region_1 = dict(zip(map_hoja1["SOO"], map_hoja1["Region_Simplified"]))
map_region_2 = dict(zip(map_hoja2["SOO"], map_hoja2["Simplified"]))

# Apply mappings to df_signals[SOO]
# Ensure df_signals["SOO"] is str or None
df_signals["SOO"] = df_signals["SOO"].astype(str)

# Step 1: Map to SOO_Chamber
chamber_labels = []
for soo in df_signals["SOO"]:
    if soo in map_chamber_1:
        chamber_labels.append(map_chamber_1[soo])
    elif soo in map_chamber_2:
        chamber_labels.append(map_chamber_2[soo])
    else:
        chamber_labels.append("OTHER")

# Normalize chamber labels to Left / Right / OTHER
def normalize_chamber(chamber):
    if chamber in ["RVOT", "Right ventricle", "Tricuspid annulus", "Coronary sinus"]:
        return "Right"
    elif chamber in ["LVOT", "Left ventricle", "Mitral annulus"]:
        return "Left"
    return "OTHER"

df_signals["SOO_Chamber_Mapped"] = chamber_labels
df_signals["normalized_label"] = [normalize_chamber(lbl) for lbl in chamber_labels]

# Step 2: Map to Region_Simplified (fine-grained anatomical label)
region_labels = []
for soo in df_signals["SOO"]:
    if soo in map_region_1:
        region_labels.append(map_region_1[soo])
    elif soo in map_region_2:
        region_labels.append(map_region_2[soo])
    else:
        region_labels.append("OTHER")

df_signals["region_label"] = region_labels

# Final overview
print("Label counts (Left vs Right):")
print(df_signals["normalized_label"].value_counts())

print("\nRegion label counts (for RVOTSEPTUM/RCC):")
print(df_signals["region_label"].value_counts())
# Out:
# Label counts (Left vs Right):
# normalized_label
# Right    23603
# Left      5478
# OTHER       72
# Name: count, dtype: int64
#
# Region label counts (for RVOTSEPTUM/RCC):
# region_label
# RVOTSEPTUM         10727
# RVOTFREEWALL        7748
# LVOTSUBVALVULAR     4392
# SUMMIT              2378
# LVOTSUMMIT          1119
# COMMISSURE          1104
# LCC                  870
# RCC                  627
# COMMISURE            116
# OTHER                 72
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Use consistent pastel palette
custom_palette = sns.color_palette("pastel")

# Plot for Left vs Right vs OTHER
plt.figure(figsize=(6, 4))
ax1 = sns.countplot(
    x="normalized_label",
    data=df_signals,
    order=["Left", "Right", "OTHER"],
    palette=custom_palette
)
plt.title("Label Counts: Left vs Right vs OTHER")
plt.xlabel("Class")
plt.ylabel("Number of ECG Samples")

for p in ax1.patches:
    height = int(p.get_height())
    ax1.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                 ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

# Plot for RCC vs RVOTSEPTUM
plt.figure(figsize=(6, 4))
df_rcc_rvot = df_signals[df_signals["region_label"].isin(["RCC", "RVOTSEPTUM"])]

ax2 = sns.countplot(
    x="region_label",
    data=df_rcc_rvot,
    order=["RCC", "RVOTSEPTUM"],
    palette=custom_palette
)
plt.title("Label Counts: RCC vs RVOTSEPTUM")
plt.xlabel("Class")
plt.ylabel("Number of ECG Samples")

for p in ax2.patches:
    height = int(p.get_height())
    ax2.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                 ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\4194828922.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.countplot(
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\4194828922.py:9: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   ax1 = sns.countplot(
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\4194828922.py:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax2 = sns.countplot(
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\4194828922.py:31: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   ax2 = sns.countplot(

# %%
# Impute numerical columns (median)
numeric_columns = ["Age", "Height", "Weight"]
df_signals[numeric_columns] = df_signals[numeric_columns].fillna(df_signals[numeric_columns].median())

# Impute categorical columns (mode)
categorical_columns = ["Sex", "PVC_transition", "DM", "DLP", "Smoker", "COPD", "Sleep_apnea"]
df_signals[categorical_columns] = df_signals[categorical_columns].apply(lambda x: x.fillna(x.mode()[0]))

# Compute BMI = weight (kg) / height (m)^2
# Ensure height is in meters (currently in cm)
df_signals["Height_m"] = df_signals["Height"] / 100
df_signals["BMI"] = df_signals["Weight"] / (df_signals["Height_m"] ** 2)

# Drop the temporary column
df_signals.drop(columns=["Height_m"], inplace=True)

# Drop the clinical score column (avoid cheating)
df_signals.drop(columns=['CLINICAL_SCORE'], inplace=True)

# Map labels to numeric values
df_signals["label"] = df_signals["normalized_label"].map({"Left": 0, "Right": 1})

# %%
map_hoja2 = pd.read_excel("data/labels_FontiersUnsupervised.xlsx", sheet_name="Hoja2")

# Clean Hoja2
map_hoja2 = map_hoja2.dropna(subset=["SOO", "OTorigin"])

# Build mapping dicts
soo_to_otorigin = dict(zip(map_hoja2["SOO"], map_hoja2["OTorigin"]))
chamber_to_otorigin = dict(zip(map_hoja2["SOO_chamber"], map_hoja2["OTorigin"]))
region_to_otorigin = dict(zip(map_hoja2["Simplified"], map_hoja2["OTorigin"]))

def impute_otorigin(row):
    if pd.notna(row["OTorigin"]):
        return row["OTorigin"]  # already filled
    
    # Try to fill based on SOO
    if row["SOO"] in soo_to_otorigin:
        return soo_to_otorigin[row["SOO"]]
    
    # Try SOO_Chamber_Mapped
    if row["SOO_Chamber_Mapped"] in chamber_to_otorigin:
        return chamber_to_otorigin[row["SOO_Chamber_Mapped"]]
    
    # Try region_label (Simplified)
    if row["region_label"] in region_to_otorigin:
        return region_to_otorigin[row["region_label"]]
    
    return None  # still missing

df_signals["OTorigin"] = df_signals.apply(impute_otorigin, axis=1)

# %%
from sklearn.model_selection import train_test_split

# Step 1: Get patient-level labels
patient_labels_lr = df_signals[df_signals["normalized_label"].isin(["Left", "Right"])]
patient_labels_lr = patient_labels_lr.groupby("PatientID")["normalized_label"].agg(lambda x: x.mode().iloc[0]).reset_index()

# Step 2: Patient-level train-test split
train_patients_lr, test_patients_lr = train_test_split(
    patient_labels_lr, stratify=patient_labels_lr["normalized_label"], test_size=0.2, random_state=42
)

# Step 3: Assign ECGs to sets
train_ids_lr = set(train_patients_lr["PatientID"])
test_ids_lr = set(test_patients_lr["PatientID"])

df_train_lr = df_signals[df_signals["PatientID"].isin(train_ids_lr) & df_signals["normalized_label"].isin(["Left", "Right"])].copy()
df_test_lr = df_signals[df_signals["PatientID"].isin(test_ids_lr) & df_signals["normalized_label"].isin(["Left", "Right"])].copy()

# Step 4: Softer balancing
left_df = df_train_lr[df_train_lr["normalized_label"] == "Left"]
right_df = df_train_lr[df_train_lr["normalized_label"] == "Right"]

# Select a number of Right samples slightly higher than Left
target_n_right = int(len(left_df) * 1.2)  # 20% more Right than Left

right_soft_sampled = right_df.sample(n=min(target_n_right, len(right_df)), random_state=42)

# Final training set
df_train_lr_balanced = pd.concat([left_df, right_soft_sampled]).sample(frac=1, random_state=42).reset_index(drop=True)

# Print class distribution
print("\nLeft vs Right (Soft Balanced)")
print("Training set:")
print(df_train_lr_balanced["normalized_label"].value_counts())
print("\nTest set:")
print(df_test_lr["normalized_label"].value_counts())
# Out:
# Left vs Right (Soft Balanced)
# Training set:
# normalized_label
# Right    5854
# Left     4879
# Name: count, dtype: int64
#
# Test set:
# normalized_label
# Right    5061
# Left      599
# Name: count, dtype: int64

# %%
# Step 1: Get patient-level labels from full df_signals
patient_labels_rvot = df_signals[df_signals["region_label"].isin(["RCC", "RVOTSEPTUM"])]
patient_labels_rvot = patient_labels_rvot.groupby("PatientID")["region_label"].agg(lambda x: x.mode().iloc[0]).reset_index()

# Step 2: Train-test split at patient level (stratifies)
train_patients_rvot, test_patients_rvot = train_test_split(
    patient_labels_rvot, stratify=patient_labels_rvot["region_label"], test_size=0.2, random_state=42
)

# Step 3: Assign ECGs to sets
train_ids_rvot = set(train_patients_rvot["PatientID"])
test_ids_rvot = set(test_patients_rvot["PatientID"])

df_train_rvot = df_signals[
    df_signals["PatientID"].isin(train_ids_rvot) &
    df_signals["region_label"].isin(["RCC", "RVOTSEPTUM"])
].copy()

df_test_rvot = df_signals[
    df_signals["PatientID"].isin(test_ids_rvot) &
    df_signals["region_label"].isin(["RCC", "RVOTSEPTUM"])
].copy()

# Step 4: Soft balance at the patient level
# Keep all RCC patients (minority class)
rcc_patients = train_patients_rvot[train_patients_rvot["region_label"] == "RCC"]
rcc_patient_ids = set(rcc_patients["PatientID"])

# Select matching number of RVOTSEPTUM patients
rvot_patients = train_patients_rvot[train_patients_rvot["region_label"] == "RVOTSEPTUM"]

# Here we choose same number as RCC
n_rcc = len(rcc_patient_ids)
n_target = min(len(rvot_patients), int(1.2 * n_rcc))
rvot_sampled = rvot_patients.sample(n=n_target, random_state=42)
rvot_patient_ids = set(rvot_sampled["PatientID"])

# Combine selected patients
balanced_train_ids = rcc_patient_ids.union(rvot_patient_ids)

# Final training set
df_train_rvot_balanced = df_train_rvot[df_train_rvot["PatientID"].isin(balanced_train_ids)].reset_index(drop=True)

# Display
print("\nRCC vs RVOTSEPTUM")
print("Balanced training set:")
print(df_train_rvot_balanced["region_label"].value_counts())
print("Unbalanced test set:")
print(df_test_rvot["region_label"].value_counts())
# Out:
# RCC vs RVOTSEPTUM
# Balanced training set:
# region_label
# RVOTSEPTUM    797
# RCC           526
# Name: count, dtype: int64
# Unbalanced test set:
# region_label
# RVOTSEPTUM    3605
# RCC            101
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_class_distribution(df_train, train_label_col, df_test, test_label_col, title_prefix, labels_map):
    plt.figure(figsize=(12, 5))

    # Training set plot
    plt.subplot(1, 2, 1)
    train_counts = df_train[train_label_col].value_counts().reindex(labels_map.keys())
    sns.barplot(x=train_counts.index, y=train_counts.values, palette="pastel")
    plt.title(f"{title_prefix} - Training Set")
    plt.ylabel("Count")
    plt.xlabel("Class")
    for i, v in enumerate(train_counts.values):
        plt.text(i, v + max(train_counts.values)*0.01, str(v), ha='center', fontsize=12)

    # Test set plot
    plt.subplot(1, 2, 2)
    test_counts = df_test[test_label_col].value_counts().reindex(labels_map.keys())
    sns.barplot(x=test_counts.index, y=test_counts.values, palette="pastel")
    plt.title(f"{title_prefix} - Test Set")
    plt.ylabel("Count")
    plt.xlabel("Class")
    for i, v in enumerate(test_counts.values):
        plt.text(i, v + max(test_counts.values)*0.01, str(v), ha='center', fontsize=12)

    plt.tight_layout()
    plt.show()

# Plot for Left vs Right
plot_class_distribution(
    df_train_lr_balanced, "normalized_label",
    df_test_lr, "normalized_label",
    title_prefix="Left vs Right",
    labels_map={"Left":0, "Right":1}
)

# Plot for RCC vs RVOTSEPTUM
plot_class_distribution(
    df_train_rvot_balanced, "region_label",
    df_test_rvot, "region_label",
    title_prefix="RCC vs RVOTSEPTUM",
    labels_map={"RCC":0, "RVOTSEPTUM":1}
)
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\2851105753.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=train_counts.index, y=train_counts.values, palette="pastel")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\2851105753.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=test_counts.index, y=test_counts.values, palette="pastel")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\2851105753.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=train_counts.index, y=train_counts.values, palette="pastel")
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\2851105753.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=test_counts.index, y=test_counts.values, palette="pastel")

# %%
import scipy.signal as sp
import numpy as np
from scipy.interpolate import interp1d

# Processes one sample ECG with all 12 leads
def preprocess_ecg_signal(ecg_signals, fs=1000, target_fs=250, high=0.5, low=100.0):
    """
    Preprocess a multi-lead ECG signal [timepoints, leads]:
    - Resample to target_fs
    - Bandpass filter between `high` and `low`
    """
    timepoints = ecg_signals.shape[0] # Initially, 2500
    new_timepoints = int(timepoints * target_fs / fs) # 625
    
    # Resample each lead using interpolation
    ecg_resampled = np.zeros((new_timepoints, ecg_signals.shape[1]))
    for lead in range(ecg_signals.shape[1]):
        f = interp1d(np.arange(timepoints), ecg_signals[:, lead]) # Interpolation function from original points
        ecg_resampled[:, lead] = f(np.linspace(0, timepoints - 1, new_timepoints)) # Create the new timeline

    # Apply high-pass filter (remove slow drifts below 0.5 Hz)
    b_high, a_high = sp.butter(2, high / (target_fs / 2), btype='high')
    ecg_filtered = sp.filtfilt(b_high, a_high, ecg_resampled, axis=0)

    # Apply low-pass filter (remove noise above 100 Hz)
    b_low, a_low = sp.butter(2, low / (target_fs / 2), btype='low')
    ecg_filtered = sp.filtfilt(b_low, a_low, ecg_filtered, axis=0)

    return ecg_filtered # Return the signal with shape [625, 12]

# %%
def align_to_r_peak(ecg_filtered, fs=250):
    """
    Align ECG segment around R peak detected in the second second (samples 250–500).
    Returns a centered window of 1.25s (312 samples) around the R peak.
    """
    lead_for_r = 1  # Lead II is commonly used for R-peak detection
    signal = ecg_filtered[:, lead_for_r]
    
    # Focus on 1s to 2s segment
    window_start, window_end = int(1 * fs), int(2 * fs)
    segment = signal[window_start:window_end]
    
    # Find R peak in that window
    r_peak_relative = np.argmax(segment)
    r_peak_absolute = window_start + r_peak_relative

    # Center a 312-sample window on R peak
    half_window = 156
    start_idx = max(0, r_peak_absolute - half_window)
    end_idx = start_idx + 312

    # If window is beyond bounds, pad accordingly
    if end_idx > ecg_filtered.shape[0]:
        pad_len = end_idx - ecg_filtered.shape[0]
        padded = np.pad(ecg_filtered, ((0, pad_len), (0, 0)), mode='constant')
        segment_aligned = padded[start_idx:end_idx]
    else:
        segment_aligned = ecg_filtered[start_idx:end_idx]

    return segment_aligned

# %%
# Apply preprocessing & r-peak alignment
ecg_leads = ['I', 'II', 'III', 'AVR', 'AVL', 'AVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']

def process_dataset(df_subset):
    processed_signals = []
    for _, row in df_subset.iterrows():
        # Extract raw ECG and transpose to [timepoints, leads]
        try:
            ecg = np.array([row["Leads"][lead] for lead in ecg_leads]).T
            filtered = preprocess_ecg_signal(ecg)
            aligned = align_to_r_peak(filtered)
            processed_signals.append(aligned)
        except Exception as e:
            print(f"Skipping a sample due to error: {e}")
    return np.stack(processed_signals)

# %%
X_train_left_right = process_dataset(df_train_lr_balanced)
X_test_left_right = process_dataset(df_test_lr)

y_train_left_right = df_train_lr_balanced["label"].values
y_test_left_right = df_test_lr["label"].values

print("Left vs Right")
print("X_train:", X_train_left_right.shape)
print("X_test:", X_test_left_right.shape)
print("y_train:", y_train_left_right.shape)
print("y_test:", y_test_left_right.shape)
# Out:
# Left vs Right
# X_train: (10733, 312, 12)
# X_test: (5660, 312, 12)
# y_train: (10733,)
# y_test: (5660,)

# %%
X_train_rcc = process_dataset(df_train_rvot_balanced)
X_test_rcc = process_dataset(df_test_rvot)

y_train_rcc = df_train_rvot_balanced["label"].values
y_test_rcc = df_test_rvot["label"].values

print("\nRCC vs RVOTSEPTUM")
print("X_train:", X_train_rcc.shape)
print("X_test:", X_test_rcc.shape)
print("y_train:", y_train_rcc.shape)
print("y_test:", y_test_rcc.shape)
# Out:
# RCC vs RVOTSEPTUM
# X_train: (1323, 312, 12)
# X_test: (3706, 312, 12)
# y_train: (1323,)
# y_test: (3706,)

# %%
# Configuration
sample_idx = 1  # Choose any index
leads_to_plot = ['I', 'AVR', 'V2']
ecg_leads = ['I', 'II', 'III', 'AVR', 'AVL', 'AVF', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6']
lead_indices = [ecg_leads.index(lead) for lead in leads_to_plot]

# Raw ECG from df_test_lr (1000Hz)
raw_leads_dict = df_test_lr.iloc[sample_idx]["Leads"]
raw_signal = np.array([raw_leads_dict[lead] for lead in ecg_leads])  # shape [12, 2500]

# Processed ECG from X_test_left_right (250Hz)
aligned_signal = X_test_left_right[sample_idx].T  # shape [12, 312]

# Time axes
t_raw = np.linspace(0, 2.5, raw_signal.shape[1])
t_aligned = np.linspace(0, 1.25, aligned_signal.shape[1])

# Plot
plt.figure(figsize=(15, 8))
for k, lead_idx in enumerate(lead_indices):
    plt.subplot(len(lead_indices), 1, k + 1)
    plt.plot(t_raw, raw_signal[lead_idx], label='Raw (1000Hz)', alpha=0.6)
    plt.plot(t_aligned, aligned_signal[lead_idx], label='Aligned (250Hz)', alpha=0.9)
    plt.title(f"Lead {ecg_leads[lead_idx]} - Sample {sample_idx}")
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

# %%
import torch 

# Load pretrained SAK models
model_dir = "data/modelos"
models = [torch.load(f"{model_dir}/model.{i+1}") for i in range(5)]
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_18724\3481763908.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   models = [torch.load(f"{model_dir}/model.{i+1}") for i in range(5)]

# %%
import numpy as np
import torch
import skimage.util
import math
from typing import List

def predict_ecg(
    ecg: np.ndarray,
    fs: int = 250,
    model: List[torch.nn.Module] = None,
    window_size: int = 2048,
    stride: int = 256,
    threshold_ensemble: float = 0.5,
    thr_dice: float = 0.9,
    ptg_voting: float = 0.5,
    batch_size: int = 16
) -> np.ndarray:
    """
    Predicts P, QRS, and T masks for a given ECG signal using an ensemble of models.

    Args:
        ecg (np.ndarray): ECG signal of shape (T, L) where T is time, L is leads.
        fs (int): Sampling frequency (default 250).
        model (list): List of PyTorch models (each predicting sigmoid mask for 3 classes).
        window_size (int): Window size in samples for model input.
        stride (int): Stride between windows.
        threshold_ensemble (float): Threshold proportion of models that must agree on a point.
        thr_dice (float): Threshold for each model’s probability output to count as a “positive”.
        ptg_voting (float): Final voting threshold on normalized votes per timepoint.
        batch_size (int): Batch size for model prediction.

    Returns:
        full_mask (np.ndarray): Binary mask of shape (3, T) for P, QRS, and T waves.
    """
    if ecg.shape[0] < 50:
        raise ValueError(f"Signal too short for segmentation: {ecg.shape}")

    ecg = np.copy(ecg)
    if ecg.ndim == 2 and ecg.shape[0] < ecg.shape[1]:
        ecg = ecg.T
    ecg = ecg[:, :12]

    N = ecg.shape[0]

    # Pad to multiple of window size
    if N < window_size:
        pad = math.ceil(N / window_size) * window_size - N
        ecg = np.pad(ecg, ((0, pad), (0, 0)), mode='edge')
    
    remainder = (ecg.shape[0] - window_size) % stride
    if remainder != 0:
        pad = stride - remainder
        ecg = np.pad(ecg, ((0, pad), (0, 0)), mode='edge')

    # Windowing
    windowed = skimage.util.view_as_windows(ecg, (window_size, ecg.shape[1]), step=(stride, 1))
    windowed = windowed[:, 0, :, :]  # (n_windows, 2048, 12)
    windowed = np.swapaxes(windowed, 1, 2)  # (n_windows, 12, 2048)

    # Model expects 1 channel per lead per window, so let's adjust the shape
    windowed = windowed.reshape(-1, 1, window_size)  # (n_windows * 12, 1, 2048)

    # Prediction
    mask = np.zeros((windowed.shape[0], 3, window_size), dtype=float)
    device = "cuda" if torch.cuda.is_available() else "cpu"

    if model is None or len(model) == 0:
        raise ValueError("No models provided for prediction.")

    # Set models to evaluation mode
    for m in model:
        m.eval()

    with torch.no_grad():
        for m in model:
            m = m.to(device)
            for i in range(0, windowed.shape[0], batch_size):
                inputs = {"x": torch.tensor(windowed[i:i+batch_size]).float().to(device)}
                output = m(inputs)
                
                # Handle model outputs based on expected type
                if isinstance(output, dict):
                    outputs = output["sigmoid"].cpu().numpy()
                else:
                    outputs = torch.sigmoid(output).cpu().numpy()
                
                mask[i:i+batch_size] += outputs > thr_dice

        # Threshold based on ensemble agreement
        mask = mask >= len(model) * threshold_ensemble

    # Reconstruct full mask
    full_len = (mask.shape[0] - 1) * stride + window_size
    full_mask = np.zeros((3, full_len))
    counter = np.zeros(full_len)

    for i in range(mask.shape[0]):
        start = i * stride
        full_mask[:, start:start+window_size] += mask[i]
        counter[start:start+window_size] += 1

    # Avoid division by zero
    counter[counter == 0] = 1
    full_mask = (full_mask / counter) > ptg_voting

    # Truncate to original length
    full_mask = full_mask[:, :N]

    return full_mask

# %%
def extract_morph_features(
    signal: np.ndarray,
    mask: np.ndarray,
    fs: int = 250
) -> dict:
    """
    Extracts R/S amplitude, ratio, QRS duration, and T polarity from a single lead.

    Args:
        signal (np.ndarray): ECG signal for one lead (T,) or (T, 1).
        mask (np.ndarray): Binary segmentation mask of shape (3, T).
        fs (int): Sampling frequency in Hz.

    Returns:
        dict: Extracted features.
    """
    features = {}
    if signal.ndim == 2:
        signal = signal[:, 0]
    if signal.shape[0] < 10 or mask.shape != (3, signal.shape[0]):
        raise ValueError("Malformed signal or mask")

    r_peak = np.max(signal)
    s_trough = np.min(signal)
    r_s_ratio = r_peak / abs(s_trough) if s_trough != 0 else 0

    qrs_indices = np.where(mask[1])[0]
    qrs_dur = (qrs_indices[-1] - qrs_indices[0]) / fs * 1000 if len(qrs_indices) > 1 else 0

    t_indices = np.where(mask[2])[0]
    if len(t_indices) > 3:
        t_mean = np.mean(signal[t_indices])
        polarity = 1 if t_mean > 0.02 else (-1 if t_mean < -0.02 else 0)
    else:
        polarity = 0

    features["r_amp"] = r_peak
    features["s_amp"] = s_trough
    features["r_s_ratio"] = r_s_ratio
    features["qrs_dur"] = qrs_dur
    features["t_polarity"] = polarity

    return features

# %%
from tqdm import tqdm

def extract_all_features(
    X_data: np.ndarray,
    id_data: List[tuple],  # List of (PatientID, SampleID, Structure)
    models: List[torch.nn.Module],
    fs: int = 250
) -> pd.DataFrame:
    """
    Extract morphological features for all ECGs and all leads.

    Args:
        X_data (np.ndarray): ECGs of shape (N, T, L)
        id_data (List[tuple]): List of tuples like (PatientID, SampleID, Structure)
        models (List[torch.nn.Module]): Ensemble of PyTorch models
        fs (int): Sampling frequency

    Returns:
        pd.DataFrame: Feature dataframe with one row per ECG
    """
    feature_rows = []

    for i in tqdm(range(len(X_data)), desc="Extracting features"):
        ecg = X_data[i]
        patient_id, sample_id, structure = id_data[i]

        try:
            mask = predict_ecg(ecg, fs=fs, model=models)

            row = {
                "PatientID": patient_id,
                "SampleID": sample_id,
                "Structure": structure
            }

            for lead_idx in range(ecg.shape[1]):
                lead_signal = ecg[:, lead_idx]
                lead_mask = mask.copy()

                try:
                    features = extract_morph_features(lead_signal, lead_mask, fs=fs)
                    for key, val in features.items():
                        row[f"lead{lead_idx+1}_{key}"] = val
                except Exception as e:
                    print(f"Feature extraction failed on sample {i}, lead {lead_idx}: {e}")
                    for key in ["r_amp", "s_amp", "r_s_ratio", "qrs_dur", "t_polarity"]:
                        row[f"lead{lead_idx+1}_{key}"] = np.nan

            feature_rows.append(row)

        except Exception as e:
            print(f"Segmentation failed on sample {i}: {e}")
            continue

    return pd.DataFrame(feature_rows)

# %%
# Build ID triplets for Left vs Right
train_ids_lr = list(zip(df_train_lr_balanced["PatientID"], df_train_lr_balanced["SampleID"], df_train_lr_balanced["Structure"]))
test_ids_lr = list(zip(df_test_lr["PatientID"], df_test_lr["SampleID"], df_test_lr["Structure"]))

# Extract features
df_train_features_lr = extract_all_features(X_train_left_right, train_ids_lr, models)
df_test_features_lr = extract_all_features(X_test_left_right, test_ids_lr, models)

# Build ID triplets for RCC vs RVOTSEPTUM
train_ids_rcc = list(zip(df_train_rvot_balanced["PatientID"], df_train_rvot_balanced["SampleID"], df_train_rvot_balanced["Structure"]))
test_ids_rcc = list(zip(df_test_rvot["PatientID"], df_test_rvot["SampleID"], df_test_rvot["Structure"]))

# Extract features
df_train_features_rcc = extract_all_features(X_train_rcc, train_ids_rcc, models)
df_test_features_rcc = extract_all_features(X_test_rcc, test_ids_rcc, models)

print("Left vs Right - Train Features:", df_train_features_lr.shape)
print("Left vs Right - Test Features:", df_test_features_lr.shape)

print("RCC vs RVOTSEPTUM - Train Features:", df_train_features_rcc.shape)
print("RCC vs RVOTSEPTUM - Test Features:", df_test_features_rcc.shape)
# Out:
# Extracting features: 100%|██████████| 10733/10733 [2:31:50<00:00,  1.18it/s]
# Extracting features: 100%|██████████| 5660/5660 [1:19:52<00:00,  1.18it/s]
# Extracting features: 100%|██████████| 1323/1323 [18:48<00:00,  1.17it/s]
# Extracting features: 100%|██████████| 3706/3706 [52:07<00:00,  1.18it/s]
# Left vs Right - Train Features: (10733, 63)
# Left vs Right - Test Features: (5660, 63)
# RCC vs RVOTSEPTUM - Train Features: (1323, 63)
# RCC vs RVOTSEPTUM - Test Features: (3706, 63)

# %%
# Merge features with metadata (Left vs Right)
df_train_lr_merged = pd.merge(df_train_features_lr, df_train_lr_balanced, on=["PatientID", "SampleID", "Structure"], how="left")
df_test_lr_merged = pd.merge(df_test_features_lr, df_test_lr, on=["PatientID", "SampleID", "Structure"], how="left")

categorical_cols = ['Sex', 'PVC_transition', 'DM', 'DLP', 'Smoker', 'COPD', 'Sleep_apnea']

df_train_lr_merged = pd.get_dummies(df_train_lr_merged, columns=categorical_cols, drop_first=True)
df_test_lr_merged = pd.get_dummies(df_test_lr_merged, columns=categorical_cols, drop_first=True)

df_test_lr_merged = df_test_lr_merged.reindex(columns=df_train_lr_merged.columns, fill_value=0)

drop_cols_lr = [
    "PatientID", "SampleID", "Structure", "Leads",
    "label", "normalized_label", "SOO", "SOO_chamber", "SOO_Chamber_Mapped", "region_label"
]

X_train_lr_all = df_train_lr_merged.drop(columns=drop_cols_lr, errors='ignore')
y_train_lr = df_train_lr_merged["label"]

X_test_lr_all = df_test_lr_merged.drop(columns=drop_cols_lr, errors='ignore')
y_test_lr = df_test_lr_merged["label"]

# Merge features with metadata (RCC vs RVOTSEPTUM)
df_train_rcc_merged = pd.merge(df_train_features_rcc, df_train_rvot_balanced, on=["PatientID", "SampleID", "Structure"], how="left")
df_test_rcc_merged = pd.merge(df_test_features_rcc, df_test_rvot, on=["PatientID", "SampleID", "Structure"], how="left")

df_train_rcc_merged = pd.get_dummies(df_train_rcc_merged, columns=categorical_cols, drop_first=True)
df_test_rcc_merged = pd.get_dummies(df_test_rcc_merged, columns=categorical_cols, drop_first=True)

df_test_rcc_merged = df_test_rcc_merged.reindex(columns=df_train_rcc_merged.columns, fill_value=0)

drop_cols_rcc = [
    "PatientID", "SampleID", "Structure", "Leads",
    "label", "normalized_label", "SOO", "SOO_chamber", "SOO_Chamber_Mapped", "region_label"
]

X_train_rcc_all = df_train_rcc_merged.drop(columns=drop_cols_rcc, errors='ignore')
y_train_rcc_final = df_train_rcc_merged["label"]

X_test_rcc_all = df_test_rcc_merged.drop(columns=drop_cols_rcc, errors='ignore')
y_test_rcc_final = df_test_rcc_merged["label"]
# ANOVA feature selection for Left vs Right
from sklearn.feature_selection import SelectKBest, f_classif

selector_lr = SelectKBest(score_func=f_classif, k=30)
X_train_lr_selected = selector_lr.fit_transform(X_train_lr_all, y_train_lr)
selected_features_lr = X_train_lr_all.columns[selector_lr.get_support()]
print("Selected features for Left vs Right:", list(selected_features_lr))

X_test_lr_selected = selector_lr.transform(X_test_lr_all)

# ANOVA feature selection for RCC vs RVOTSEPTUM
selector_rcc = SelectKBest(score_func=f_classif, k=30)
X_train_rcc_selected = selector_rcc.fit_transform(X_train_rcc_all, y_train_rcc_final)
selected_features_rcc = X_train_rcc_all.columns[selector_rcc.get_support()]
print("Selected features for RCC vs RVOTSEPTUM:", list(selected_features_rcc))

X_test_rcc_selected = selector_rcc.transform(X_test_rcc_all)
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# MI feature selection for Left vs Right
selector_lr_mi = SelectKBest(score_func=mutual_info_classif, k=30)
X_train_lr_selected_mi = selector_lr_mi.fit_transform(X_train_lr_all, y_train_lr)
selected_features_lr_mi = X_train_lr_all.columns[selector_lr_mi.get_support()]
print("Selected features with MI for Left vs Right:", list(selected_features_lr_mi))

X_test_lr_selected_mi = selector_lr_mi.transform(X_test_lr_all)

# MI feature selection for RCC vs RVOTSEPTUM
selector_rcc_mi = SelectKBest(score_func=mutual_info_classif, k=30)
X_train_rcc_selected_mi = selector_rcc_mi.fit_transform(X_train_rcc_all, y_train_rcc_final)
selected_features_rcc_mi = X_train_rcc_all.columns[selector_rcc_mi.get_support()]
print("Selected features with MI for RCC vs RVOTSEPTUM:", list(selected_features_rcc_mi))

X_test_rcc_selected_mi = selector_rcc_mi.transform(X_test_rcc_all)
# Out:
# Selected features for Left vs Right: ['lead2_t_polarity', 'lead3_r_amp', 'lead3_t_polarity', 'lead4_s_amp', 'lead4_t_polarity', 'lead5_r_amp', 'lead5_r_s_ratio', 'lead6_t_polarity', 'lead7_s_amp', 'lead7_t_polarity', 'lead8_s_amp', 'lead8_t_polarity', 'lead9_r_amp', 'lead9_t_polarity', 'lead10_r_amp', 'lead10_s_amp', 'lead10_t_polarity', 'lead11_r_amp', 'lead11_s_amp', 'lead11_t_polarity', 'lead12_r_amp', 'Height', 'Sex_Male', 'PVC_transition_V2', 'PVC_transition_V3', 'PVC_transition_V4', 'PVC_transition_V5', 'PVC_transition_V6', 'Smoker_Yes', 'COPD_Yes']
# Selected features for RCC vs RVOTSEPTUM: ['lead1_r_amp', 'lead1_s_amp', 'lead1_r_s_ratio', 'lead1_t_polarity', 'lead2_s_amp', 'lead3_r_amp', 'lead3_s_amp', 'lead4_r_amp', 'lead4_s_amp', 'lead6_s_amp', 'lead8_r_amp', 'lead8_s_amp', 'lead9_r_s_ratio', 'lead9_t_polarity', 'lead10_r_amp', 'lead10_t_polarity', 'lead11_r_amp', 'lead11_s_amp', 'lead12_r_amp', 'lead12_s_amp', 'Age', 'Height', 'Weight', 'BMI', 'OTorigin', 'PVC_transition_V2', 'PVC_transition_V3', 'PVC_transition_V4', 'DLP_Yes', 'Sleep_apnea_Yes']
# Selected features with MI for Left vs Right: ['lead1_r_amp', 'lead1_s_amp', 'lead2_r_amp', 'lead2_s_amp', 'lead2_r_s_ratio', 'lead3_r_s_ratio', 'lead4_s_amp', 'lead6_r_amp', 'lead6_s_amp', 'lead6_r_s_ratio', 'lead7_r_amp', 'lead7_r_s_ratio', 'lead8_r_amp', 'lead8_s_amp', 'lead8_r_s_ratio', 'lead9_r_amp', 'lead9_s_amp', 'lead9_r_s_ratio', 'lead10_r_amp', 'lead10_s_amp', 'lead10_r_s_ratio', 'lead11_r_amp', 'lead11_s_amp', 'lead11_r_s_ratio', 'lead12_r_amp', 'lead12_s_amp', 'Age', 'Height', 'Weight', 'BMI']
# Selected features with MI for RCC vs RVOTSEPTUM: ['lead1_s_amp', 'lead1_r_s_ratio', 'lead1_t_polarity', 'lead2_s_amp', 'lead3_r_amp', 'lead3_s_amp', 'lead4_s_amp', 'lead4_r_s_ratio', 'lead5_s_amp', 'lead6_s_amp', 'lead6_r_s_ratio', 'lead7_r_amp', 'lead7_s_amp', 'lead8_r_amp', 'lead8_s_amp', 'lead8_r_s_ratio', 'lead9_r_amp', 'lead9_s_amp', 'lead9_r_s_ratio', 'lead10_r_amp', 'lead11_r_amp', 'lead11_s_amp', 'lead12_r_amp', 'lead12_s_amp', 'Age', 'Height', 'Weight', 'BMI', 'PVC_transition_V3', 'PVC_transition_V4']

# %%
# !pip install xgboost

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (0.44.1)
# Requirement already satisfied: numpy in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (1.24.3)
# Requirement already satisfied: scipy in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (1.10.1)
# Requirement already satisfied: scikit-learn in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (1.3.0)
# Requirement already satisfied: pandas in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (2.0.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (24.1)
# Requirement already satisfied: slicer==0.0.7 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: importlib-metadata in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from numba->shap) (7.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\usuario\anaconda3\envs\compbiomed\lib\site-packages (from importlib-metadata->numba->shap) (3.20.2)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import shap as shap

# Define reusable function to train and evaluate multiple models with hyperparameter tuning
def train_and_evaluate_models_with_gridsearch(X_train, y_train, X_test, y_test, label_names,  feature_names, task_name=""):
    X_train = np.array(X_train)
    X_test = np.array(X_test)

    model_grid = {
        "Logistic Regression": (
            LogisticRegression(max_iter=5000, random_state=42),
            {"C": [0.01, 0.1, 1, 10], "penalty": ["l2"], "solver": ["lbfgs"]}
        ),
        "SVM (RBF)": (
            SVC(probability=True, random_state=42),
            {"C": [0.1, 1, 10], "gamma": ["scale", "auto"], "kernel": ["rbf"]}
        ),
        "k-NN": (
            KNeighborsClassifier(),
            {"n_neighbors": [3, 5, 7], "weights": ["uniform", "distance"]}
        ),
        "Gradient Boosting": (
            GradientBoostingClassifier(random_state=42),
            {"n_estimators": [50, 100], "learning_rate": [0.01, 0.1], "max_depth": [3, 5]}
        ),
        "MLP": (
            MLPClassifier(max_iter=2000, random_state=42),
            {"hidden_layer_sizes": [(50,), (100,), (100, 50)], "activation": ["relu", "tanh"]}
        ),
        "Random Forest": (
            RandomForestClassifier(random_state=42),
            {"n_estimators": [100, 200], "max_depth": [None, 10, 20]}
        ),
        "XGBoost": (
            XGBClassifier(random_state=42, eval_metric='logloss'),
            {"n_estimators": [100, 200], "learning_rate": [0.05, 0.1], "max_depth": [3, 6]}
        )
    }

  
    for name, (model, param_grid) in model_grid.items():
        print(f"\n{name} for {task_name}")

        # Use single-threaded GridSearchCV for XGBoost to avoid multiprocessing issues on macOS
        if name == "XGBoost":
            grid = GridSearchCV(model, param_grid, cv=3, scoring="accuracy", n_jobs=1)
        else:
            grid = GridSearchCV(model, param_grid, cv=3, scoring="accuracy", n_jobs=-1)

        grid.fit(X_train, y_train)
        best_model = grid.best_estimator_
        print("Best Params:", grid.best_params_)

        y_pred = best_model.predict(X_test)

        # Confusion Matrix
        plt.figure(figsize=(8, 6))
        sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_names, yticklabels=label_names)
        plt.title(f"Confusion Matrix: {name} - {task_name}")
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.show()

        # Classification Report
        print(f"Classification Report: {name} - {task_name}\n")
        print(classification_report(y_test, y_pred, target_names=label_names))
        # Convert arrays to DataFrames with names if not already
        if isinstance(X_train, np.ndarray):
            X_train = pd.DataFrame(X_train, columns=feature_names)
            X_test = pd.DataFrame(X_test, columns=feature_names)

        # --- SHAP Analysis for interpretable models only ---
        if name in ["Random Forest", "XGBoost", "Gradient Boosting", "Logistic Regression"]:
            print("Running SHAP analysis...")

            X_sample = shap.sample(X_test, 100, random_state=42) if X_test.shape[0] > 100 else X_test

            if name == "Logistic Regression":
                explainer = shap.Explainer(best_model, X_train, feature_names=feature_names)
                shap_values = explainer(X_sample)
                shap.summary_plot(shap_values, X_sample, show=True)
            else:
                explainer = shap.TreeExplainer(best_model)
                shap_values = explainer.shap_values(X_sample)

                # Handle classifiers with shap_values as a list (e.g., one per class)
                if isinstance(shap_values, list):
                    shap.summary_plot(shap_values[1], X_sample, show=True)  # class 1 explanation
                else:
                    shap.summary_plot(shap_values, X_sample, show=True)

# %%
# ANOVA for Left vs Right
train_and_evaluate_models_with_gridsearch(
    X_train_lr_selected, y_train_lr,
    X_test_lr_selected, y_test_lr,
    label_names=["Left", "Right"],
    task_name="Left vs Right (ANOVA)",
    feature_names=selected_features_lr.tolist()
    )

# MI for Left vs Right
train_and_evaluate_models_with_gridsearch(
    X_train_lr_selected_mi, y_train_lr,
    X_test_lr_selected_mi, y_test_lr,
    label_names=["Left", "Right"],
    task_name="Left vs Right (MI)",
    feature_names=selected_features_lr_mi.tolist()
    )

# ANOVA for RCC vs RVOTSEPTUM
train_and_evaluate_models_with_gridsearch(
    X_train_rcc_selected, y_train_rcc_final,
    X_test_rcc_selected, y_test_rcc_final,
    label_names=["RCC", "RVOTSEPTUM"],
    task_name="RCC vs RVOTSEPTUM (ANOVA)",
    feature_names=selected_features_rcc.tolist()
    )

# MI for RCC vs RVOTSEPTUM
train_and_evaluate_models_with_gridsearch(
    X_train_rcc_selected_mi, y_train_rcc_final,
    X_test_rcc_selected_mi, y_test_rcc_final,
    label_names=["RCC", "RVOTSEPTUM"],
    task_name="RCC vs RVOTSEPTUM (MI)",
    feature_names=selected_features_rcc_mi.tolist()
    )
# Out:
# Logistic Regression for Left vs Right (ANOVA)
# Best Params: {'C': 10, 'penalty': 'l2', 'solver': 'lbfgs'}
# Classification Report: Logistic Regression - Left vs Right (ANOVA)
#
#               precision    recall  f1-score   support
#
#         Left       0.17      0.87      0.28       599
#        Right       0.97      0.49      0.65      5061
#
#     accuracy                           0.53      5660
#    macro avg       0.57      0.68      0.47      5660
# weighted avg       0.88      0.53      0.61      5660
#
# Running SHAP analysis...
# SVM (RBF) for Left vs Right (ANOVA)
# Best Params: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Classification Report: SVM (RBF) - Left vs Right (ANOVA)
#
#               precision    recall  f1-score   support
#
#         Left       0.19      0.49      0.28       599
#        Right       0.93      0.75      0.83      5061
#
#     accuracy                           0.72      5660
#    macro avg       0.56      0.62      0.55      5660
# weighted avg       0.85      0.72      0.77      5660
#
#
# k-NN for Left vs Right (ANOVA)
# One or more of the test scores are non-finite: [       nan 0.98826074        nan 0.98677002        nan 0.98490662]
# Best Params: {'n_neighbors': 3, 'weights': 'distance'}
# Classification Report: k-NN - Left vs Right (ANOVA)
#
#               precision    recall  f1-score   support
#
#         Left       0.20      0.55      0.29       599
#        Right       0.93      0.73      0.82      5061
#
#     accuracy                           0.71      5660
#    macro avg       0.56      0.64      0.56      5660
# weighted avg       0.85      0.71      0.76      5660
#
#
# Gradient Boosting for Left vs Right (ANOVA)
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# Classification Report: Gradient Boosting - Left vs Right (ANOVA)
#
#               precision    recall  f1-score   support
#
#         Left       0.24      0.57      0.33       599
#        Right       0.94      0.78      0.85      5061
#
#     accuracy                           0.76      5660
#    macro avg       0.59      0.67      0.59      5660
# weighted avg       0.86      0.76      0.80      5660
#
# Running SHAP analysis...
# MLP for Left vs Right (ANOVA)
# Best Params: {'activation': 'tanh', 'hidden_layer_sizes': (100, 50)}
# Classification Report: MLP - Left vs Right (ANOVA)
#
#               precision    recall  f1-score   support
#
#         Left       0.16      0.42      0.23       599
#        Right       0.91      0.74      0.82      5061
#
#     accuracy                           0.70      5660
#    macro avg       0.54      0.58      0.52      5660
# weighted avg       0.83      0.70      0.75      5660
#
#
# Random Forest for Left vs Right (ANOVA)
# Best Params: {'max_depth': 20, 'n_estimators': 200}
# Classification Report: Random Forest - Left vs Right (ANOVA)
#
#               precision    recall  f1-score   support
#
#         Left       0.38      0.45      0.41       599
#        Right       0.93      0.91      0.92      5061
#
#     accuracy                           0.86      5660
#    macro avg       0.65      0.68      0.67      5660
# weighted avg       0.87      0.86      0.87      5660
#
# Running SHAP analysis...
# XGBoost for Left vs Right (ANOVA)
# Best Params: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200}
# Classification Report: XGBoost - Left vs Right (ANOVA)
#
#               precision    recall  f1-score   support
#
#         Left       0.21      0.44      0.28       599
#        Right       0.92      0.80      0.86      5061
#
#     accuracy                           0.76      5660
#    macro avg       0.56      0.62      0.57      5660
# weighted avg       0.85      0.76      0.79      5660
#
# Running SHAP analysis...
# Logistic Regression for Left vs Right (MI)
# Best Params: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# Classification Report: Logistic Regression - Left vs Right (MI)
#
#               precision    recall  f1-score   support
#
#         Left       0.18      0.84      0.30       599
#        Right       0.97      0.54      0.70      5061
#
#     accuracy                           0.58      5660
#    macro avg       0.57      0.69      0.50      5660
# weighted avg       0.88      0.58      0.65      5660
#
# Running SHAP analysis...
# SVM (RBF) for Left vs Right (MI)
# Best Params: {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# Classification Report: SVM (RBF) - Left vs Right (MI)
#
#               precision    recall  f1-score   support
#
#         Left       0.26      0.15      0.19       599
#        Right       0.90      0.95      0.93      5061
#
#     accuracy                           0.87      5660
#    macro avg       0.58      0.55      0.56      5660
# weighted avg       0.84      0.87      0.85      5660
#
#
# k-NN for Left vs Right (MI)
# One or more of the test scores are non-finite: [       nan 0.99822977        nan 0.99776391        nan 0.99739118]
# Best Params: {'n_neighbors': 3, 'weights': 'distance'}
# Classification Report: k-NN - Left vs Right (MI)
#
#               precision    recall  f1-score   support
#
#         Left       0.04      0.15      0.07       599
#        Right       0.86      0.60      0.71      5061
#
#     accuracy                           0.56      5660
#    macro avg       0.45      0.38      0.39      5660
# weighted avg       0.77      0.56      0.64      5660
#
#
# Gradient Boosting for Left vs Right (MI)
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# Classification Report: Gradient Boosting - Left vs Right (MI)
#
#               precision    recall  f1-score   support
#
#         Left       0.32      0.48      0.38       599
#        Right       0.93      0.88      0.91      5061
#
#     accuracy                           0.84      5660
#    macro avg       0.63      0.68      0.64      5660
# weighted avg       0.87      0.84      0.85      5660
#
# Running SHAP analysis...
# MLP for Left vs Right (MI)
# Best Params: {'activation': 'tanh', 'hidden_layer_sizes': (100,)}
# Classification Report: MLP - Left vs Right (MI)
#
#               precision    recall  f1-score   support
#
#         Left       0.15      0.52      0.24       599
#        Right       0.92      0.66      0.77      5061
#
#     accuracy                           0.65      5660
#    macro avg       0.54      0.59      0.50      5660
# weighted avg       0.84      0.65      0.71      5660
#
#
# Random Forest for Left vs Right (MI)
# Best Params: {'max_depth': 20, 'n_estimators': 100}
# Classification Report: Random Forest - Left vs Right (MI)
#
#               precision    recall  f1-score   support
#
#         Left       0.15      0.17      0.16       599
#        Right       0.90      0.89      0.89      5061
#
#     accuracy                           0.81      5660
#    macro avg       0.53      0.53      0.53      5660
# weighted avg       0.82      0.81      0.82      5660
#
# Running SHAP analysis...
# XGBoost for Left vs Right (MI)
# Best Params: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200}
# Classification Report: XGBoost - Left vs Right (MI)
#
#               precision    recall  f1-score   support
#
#         Left       0.30      0.41      0.34       599
#        Right       0.93      0.89      0.91      5061
#
#     accuracy                           0.84      5660
#    macro avg       0.61      0.65      0.62      5660
# weighted avg       0.86      0.84      0.85      5660
#
# Running SHAP analysis...
# Logistic Regression for RCC vs RVOTSEPTUM (ANOVA)
# Best Params: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# Classification Report: Logistic Regression - RCC vs RVOTSEPTUM (ANOVA)
#
#               precision    recall  f1-score   support
#
#          RCC       0.07      1.00      0.13       101
#   RVOTSEPTUM       1.00      0.62      0.77      3605
#
#     accuracy                           0.63      3706
#    macro avg       0.53      0.81      0.45      3706
# weighted avg       0.97      0.63      0.75      3706
#
# Running SHAP analysis...
# SVM (RBF) for RCC vs RVOTSEPTUM (ANOVA)
# Best Params: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Classification Report: SVM (RBF) - RCC vs RVOTSEPTUM (ANOVA)
#
#               precision    recall  f1-score   support
#
#          RCC       0.06      1.00      0.12       101
#   RVOTSEPTUM       1.00      0.59      0.75      3605
#
#     accuracy                           0.61      3706
#    macro avg       0.53      0.80      0.43      3706
# weighted avg       0.97      0.61      0.73      3706
#
#
# k-NN for RCC vs RVOTSEPTUM (ANOVA)
# Best Params: {'n_neighbors': 3, 'weights': 'distance'}
# One or more of the test scores are non-finite: [       nan 0.65079365        nan 0.65079365        nan 0.65079365]
# Classification Report: k-NN - RCC vs RVOTSEPTUM (ANOVA)
#
#               precision    recall  f1-score   support
#
#          RCC       0.02      0.39      0.05       101
#   RVOTSEPTUM       0.97      0.57      0.72      3605
#
#     accuracy                           0.57      3706
#    macro avg       0.50      0.48      0.38      3706
# weighted avg       0.94      0.57      0.70      3706
#
#
# Gradient Boosting for RCC vs RVOTSEPTUM (ANOVA)
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Classification Report: Gradient Boosting - RCC vs RVOTSEPTUM (ANOVA)
#
#               precision    recall  f1-score   support
#
#          RCC       0.05      1.00      0.09       101
#   RVOTSEPTUM       1.00      0.46      0.63      3605
#
#     accuracy                           0.48      3706
#    macro avg       0.52      0.73      0.36      3706
# weighted avg       0.97      0.48      0.62      3706
#
# Running SHAP analysis...
# MLP for RCC vs RVOTSEPTUM (ANOVA)
# Best Params: {'activation': 'relu', 'hidden_layer_sizes': (50,)}
# Classification Report: MLP - RCC vs RVOTSEPTUM (ANOVA)
#
#               precision    recall  f1-score   support
#
#          RCC       0.05      1.00      0.10       101
#   RVOTSEPTUM       1.00      0.49      0.66      3605
#
#     accuracy                           0.51      3706
#    macro avg       0.53      0.75      0.38      3706
# weighted avg       0.97      0.51      0.64      3706
#
#
# Random Forest for RCC vs RVOTSEPTUM (ANOVA)
# Best Params: {'max_depth': None, 'n_estimators': 200}
# Classification Report: Random Forest - RCC vs RVOTSEPTUM (ANOVA)
#
#               precision    recall  f1-score   support
#
#          RCC       0.05      1.00      0.10       101
#   RVOTSEPTUM       1.00      0.49      0.66      3605
#
#     accuracy                           0.50      3706
#    macro avg       0.53      0.75      0.38      3706
# weighted avg       0.97      0.50      0.64      3706
#
# Running SHAP analysis...
# XGBoost for RCC vs RVOTSEPTUM (ANOVA)
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Classification Report: XGBoost - RCC vs RVOTSEPTUM (ANOVA)
#
#               precision    recall  f1-score   support
#
#          RCC       0.05      1.00      0.09       101
#   RVOTSEPTUM       1.00      0.46      0.63      3605
#
#     accuracy                           0.48      3706
#    macro avg       0.52      0.73      0.36      3706
# weighted avg       0.97      0.48      0.62      3706
#
# Running SHAP analysis...
# Logistic Regression for RCC vs RVOTSEPTUM (MI)
# Best Params: {'C': 1, 'penalty': 'l2', 'solver': 'lbfgs'}
# Classification Report: Logistic Regression - RCC vs RVOTSEPTUM (MI)
#
#               precision    recall  f1-score   support
#
#          RCC       0.04      0.85      0.08       101
#   RVOTSEPTUM       0.99      0.45      0.62      3605
#
#     accuracy                           0.46      3706
#    macro avg       0.52      0.65      0.35      3706
# weighted avg       0.96      0.46      0.60      3706
#
# Running SHAP analysis...
# SVM (RBF) for RCC vs RVOTSEPTUM (MI)
# Best Params: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Classification Report: SVM (RBF) - RCC vs RVOTSEPTUM (MI)
#
#               precision    recall  f1-score   support
#
#          RCC       0.06      1.00      0.12       101
#   RVOTSEPTUM       1.00      0.57      0.73      3605
#
#     accuracy                           0.58      3706
#    macro avg       0.53      0.79      0.42      3706
# weighted avg       0.97      0.58      0.71      3706
#
#
# k-NN for RCC vs RVOTSEPTUM (MI)
# Best Params: {'n_neighbors': 3, 'weights': 'distance'}
# One or more of the test scores are non-finite: [       nan 0.65079365        nan 0.65079365        nan 0.65079365]
# Classification Report: k-NN - RCC vs RVOTSEPTUM (MI)
#
#               precision    recall  f1-score   support
#
#          RCC       0.02      0.39      0.05       101
#   RVOTSEPTUM       0.97      0.57      0.72      3605
#
#     accuracy                           0.57      3706
#    macro avg       0.50      0.48      0.38      3706
# weighted avg       0.94      0.57      0.70      3706
#
#
# Gradient Boosting for RCC vs RVOTSEPTUM (MI)
# Best Params: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50}
# Classification Report: Gradient Boosting - RCC vs RVOTSEPTUM (MI)
#
#               precision    recall  f1-score   support
#
#          RCC       0.03      0.61      0.06       101
#   RVOTSEPTUM       0.98      0.51      0.67      3605
#
#     accuracy                           0.51      3706
#    macro avg       0.51      0.56      0.37      3706
# weighted avg       0.95      0.51      0.65      3706
#
# Running SHAP analysis...
# MLP for RCC vs RVOTSEPTUM (MI)
# Best Params: {'activation': 'relu', 'hidden_layer_sizes': (100,)}
# Classification Report: MLP - RCC vs RVOTSEPTUM (MI)
#
#               precision    recall  f1-score   support
#
#          RCC       0.05      1.00      0.09       101
#   RVOTSEPTUM       1.00      0.41      0.58      3605
#
#     accuracy                           0.43      3706
#    macro avg       0.52      0.71      0.34      3706
# weighted avg       0.97      0.43      0.57      3706
#
#
# Random Forest for RCC vs RVOTSEPTUM (MI)
# Best Params: {'max_depth': None, 'n_estimators': 200}
# Classification Report: Random Forest - RCC vs RVOTSEPTUM (MI)
#
#               precision    recall  f1-score   support
#
#          RCC       0.05      1.00      0.10       101
#   RVOTSEPTUM       1.00      0.50      0.67      3605
#
#     accuracy                           0.51      3706
#    macro avg       0.53      0.75      0.38      3706
# weighted avg       0.97      0.51      0.65      3706
#
# Running SHAP analysis...
# XGBoost for RCC vs RVOTSEPTUM (MI)
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Classification Report: XGBoost - RCC vs RVOTSEPTUM (MI)
#
#               precision    recall  f1-score   support
#
#          RCC       0.04      1.00      0.08       101
#   RVOTSEPTUM       1.00      0.33      0.50      3605
#
#     accuracy                           0.35      3706
#    macro avg       0.52      0.67      0.29      3706
# weighted avg       0.97      0.35      0.48      3706
#
# Running SHAP analysis...
